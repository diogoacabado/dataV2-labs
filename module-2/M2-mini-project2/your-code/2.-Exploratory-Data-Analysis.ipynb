# %% [markdown]
# # Inferential statistics
# ## Part II - Exploratory Data Analysis
#
# Before starting the actual analysis it's a good idea to explore the data that we will be using, to give yourself a first idea of the questions you will be able to answer with your data, the bias you could have, other data you could need, etc.
#
# ### Libraries
# In addition to pandas we will also import matplolib and seaborn so that we will able to plot our data to better understand it.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline
pd.set_option('max_columns', 100)

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf

# %%
# For Notebooks
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# For offline use
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Explore the dataset
#
# Let's load the cleaned dataset first. Import it with the name `wnba` and show the head.

# %%
#your code here
wnba = pd.read_csv('../data/wnba_clean.csv')

# %%
wnba.head()
# Out:
#               Name Team  Pos  Height  Weight        BMI Birth_Place  \
# 0    Aerial Powers  DAL    F     183      71  21.200991          US
# 1      Alana Beard   LA  G/F     185      73  21.329438          US
# 2     Alex Bentley  CON    G     170      69  23.875433          US
# 3  Alex Montgomery  SAN  G/F     185      84  24.543462          US
# 4     Alexis Jones  MIN    G     175      78  25.469388          US
#
#            Birthdate  Age         College Experience  Games Played  MIN  FGM  \
# 0   January 17, 1994   23  Michigan State          2             8  173   30
# 1       May 14, 1982   35            Duke         12            30  947   90
# 2   October 27, 1990   26      Penn State          4            26  617   82
# 3  December 11, 1988   28    Georgia Tech          6            31  721   75
# 4     August 5, 1994   23          Baylor          R            24  137   16
#
#    FGA   FG%  3PM  3PA   3P%  FTM  FTA   FT%  OREB  DREB  REB  AST  STL  BLK  \
# ...

# %%
wnba.shape
# Out:
# (142, 32)

# %% [markdown]
# **Use describe() to take an initial look at the data.**

# %%
#your code here
wnba.describe()
# Out:
#            Height      Weight         BMI         Age  Games Played  \
# count  142.000000  142.000000  142.000000  142.000000    142.000000
# mean   184.612676   78.978873   23.091214   27.112676     24.429577
# std      8.698128   10.996110    2.073691    3.667180      7.075477
# min    165.000000   55.000000   18.390675   21.000000      2.000000
# 25%    175.750000   71.500000   21.785876   24.000000     22.000000
# 50%    185.000000   79.000000   22.873314   27.000000     27.500000
# 75%    191.000000   86.000000   24.180715   30.000000     29.000000
# max    206.000000  113.000000   31.555880   36.000000     32.000000
#
#                MIN         FGM         FGA         FG%         3PM  \
# count   142.000000  142.000000  142.000000  142.000000  142.000000
# mean    500.105634   74.401408  168.704225   43.102817   14.830986
# std     289.373393   55.980754  117.165809    9.855199   17.372829
# min      12.000000    1.000000    3.000000   16.700000    0.000000
# ...

# %% [markdown]
# Most of the game-related stats have a very high range of values which can be explained by the fact that the dataset contains data on both players that play the majority of games and also players that may spend almost the entirety of the season on the bench.
#
# There are also some extremes in the weight and age columns. Feel free, if you'd like, to check which are the players with a very high (or low) age/weight and do some research on them. This is useful to confirm that they are simply outliers and not errors in the data.

# %%
# Heights
wnba['Height'].iplot(xTitle='Player Id', yTitle='Height')
# Out:
# <div>
#
#
#             <div id="95c6179b-f676-483a-9f25-9b02b44f38ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("95c6179b-f676-483a-9f25-9b02b44f38ef")) {
#                     Plotly.newPlot(
#                         '95c6179b-f676-483a-9f25-9b02b44f38ef',
# ...

# %%
tallest_player = wnba.iloc[25][['Name', 'Height']]
shortest_player = wnba.iloc[86][['Name', 'Height']]

# %%
# Weights
wnba['Weight'].iplot(xTitle='Player Id', yTitle='Weight')
# Out:
# <div>
#
#
#             <div id="2e5da40a-99d8-469e-9b07-7c833f8394f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2e5da40a-99d8-469e-9b07-7c833f8394f3")) {
#                     Plotly.newPlot(
#                         '2e5da40a-99d8-469e-9b07-7c833f8394f3',
# ...

# %%
heavier_player = wnba.iloc[12][['Name', 'Weight']]
lighter_player = wnba.iloc[96][['Name', 'Weight']]

# %%
# Age
wnba['Age'].iplot(xTitle='Player Id', yTitle='Age')
# Out:
# <div>
#
#
#             <div id="3172822b-8273-44a8-93b1-acc48019ba0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3172822b-8273-44a8-93b1-acc48019ba0e")) {
#                     Plotly.newPlot(
#                         '3172822b-8273-44a8-93b1-acc48019ba0e',
# ...

# %%
oldest_player = wnba.iloc[126][['Name', 'Age']]
youngest_player = wnba.iloc[15][['Name', 'Age']]

# %%
# BMI
wnba['BMI'].iplot(xTitle='Player Id', yTitle='BMI')
# Out:
# <div>
#
#
#             <div id="54c2b293-6490-4b53-a1d8-98c8bb13b29e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("54c2b293-6490-4b53-a1d8-98c8bb13b29e")) {
#                     Plotly.newPlot(
#                         '54c2b293-6490-4b53-a1d8-98c8bb13b29e',
# ...

# %%
highest_BMI = wnba.iloc[41][['Name', 'BMI']]
lowest_BMI = wnba.iloc[62][['Name', 'BMI']]

# %% [markdown]
# ### Looking at the distributions of the data
# Let's take a look at the distribution of the 4 stats that describe the physical characteristics of the players.
#
# **Plot the four distributions about `height`, `weight`, `age` and `BMI`.**

# %%
# Height
wnba['Height'].iplot(kind='box', boxpoints='all', yTitle='Height')
# Out:
# <div>
#
#
#             <div id="9ba517cf-2839-47e3-8eda-6d0f11fd258f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9ba517cf-2839-47e3-8eda-6d0f11fd258f")) {
#                     Plotly.newPlot(
#                         '9ba517cf-2839-47e3-8eda-6d0f11fd258f',
# ...

# %%
wnba['Height'].iplot(kind='hist',bins=20, xTitle='Height', yTitle='Number of players')
# Out:
# <div>
#
#
#             <div id="17146eae-020d-4083-ad56-e8ddebc6d866" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("17146eae-020d-4083-ad56-e8ddebc6d866")) {
#                     Plotly.newPlot(
#                         '17146eae-020d-4083-ad56-e8ddebc6d866',
# ...

# %%
# Weight
wnba['Weight'].iplot(kind='box', boxpoints='all', yTitle='Weight')
# Out:
# <div>
#
#
#             <div id="02c46d5e-34e2-4e3d-a5bf-d1a1152934c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("02c46d5e-34e2-4e3d-a5bf-d1a1152934c5")) {
#                     Plotly.newPlot(
#                         '02c46d5e-34e2-4e3d-a5bf-d1a1152934c5',
# ...

# %%
wnba['Weight'].iplot(kind='hist',bins=50, xTitle='Weight', yTitle='Number of players')
# Out:
# <div>
#
#
#             <div id="fda28408-141d-4c4a-b86e-1bd8b5c5635b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("fda28408-141d-4c4a-b86e-1bd8b5c5635b")) {
#                     Plotly.newPlot(
#                         'fda28408-141d-4c4a-b86e-1bd8b5c5635b',
# ...

# %%
# Age
wnba['Age'].iplot(kind='box', boxpoints='all', yTitle='Age')
# Out:
# <div>
#
#
#             <div id="9f452aed-b48c-4c14-be05-0ebc496ab30f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9f452aed-b48c-4c14-be05-0ebc496ab30f")) {
#                     Plotly.newPlot(
#                         '9f452aed-b48c-4c14-be05-0ebc496ab30f',
# ...

# %%
wnba['Age'].iplot(kind='hist',bins=10, xTitle='Age', yTitle='Number of players')
# Out:
# <div>
#
#
#             <div id="54f916f6-dd00-4cad-ae53-aa34cce9bc42" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("54f916f6-dd00-4cad-ae53-aa34cce9bc42")) {
#                     Plotly.newPlot(
#                         '54f916f6-dd00-4cad-ae53-aa34cce9bc42',
# ...

# %%
# BMI
wnba['BMI'].iplot(kind='box', boxpoints='all', yTitle='BMI')
# Out:
# <div>
#
#
#             <div id="51a6d36a-9091-4824-807c-a644e08d3cb7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("51a6d36a-9091-4824-807c-a644e08d3cb7")) {
#                     Plotly.newPlot(
#                         '51a6d36a-9091-4824-807c-a644e08d3cb7',
# ...

# %%
wnba['BMI'].iplot(kind='hist',bins=20, xTitle='BMI', yTitle='Number of players')
# Out:
# <div>
#
#
#             <div id="20399899-3747-4d7d-9821-69678286d203" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("20399899-3747-4d7d-9821-69678286d203")) {
#                     Plotly.newPlot(
#                         '20399899-3747-4d7d-9821-69678286d203',
# ...

# %%
fig = px.scatter_matrix(wnba[['Height', 'Weight', 'Age', 'BMI']])
fig.show()
# Out:
# <div>
#
#
#             <div id="6c648538-8cc8-4623-9a8c-33194eec36da" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6c648538-8cc8-4623-9a8c-33194eec36da")) {
#                     Plotly.newPlot(
#                         '6c648538-8cc8-4623-9a8c-33194eec36da',
# ...

# %%
fig = px.scatter(data_frame=wnba, x='Height', y='Weight')
fig.show()
# Out:
# <div>
#
#
#             <div id="6eb9de70-8518-4f7b-9df8-5e8c3c063271" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6eb9de70-8518-4f7b-9df8-5e8c3c063271")) {
#                     Plotly.newPlot(
#                         '6eb9de70-8518-4f7b-9df8-5e8c3c063271',
# ...

# %%
ratio = wnba['Weight']/wnba['Height']**2

# %%
fig = px.scatter(data_frame=wnba, x='BMI', y='Weight')
fig.show()
# Out:
# <div>
#
#
#             <div id="88d89fa0-4389-4b2d-ab2b-ba0f2baeeb11" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("88d89fa0-4389-4b2d-ab2b-ba0f2baeeb11")) {
#                     Plotly.newPlot(
#                         '88d89fa0-4389-4b2d-ab2b-ba0f2baeeb11',
# ...

# %%
fig = px.scatter(x=ratio, y=wnba['BMI'])
fig.show()
# Out:
# <div>
#
#
#             <div id="52c3a9fc-47a2-47c3-9bc4-8e788c47e7c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("52c3a9fc-47a2-47c3-9bc4-8e788c47e7c1")) {
#                     Plotly.newPlot(
#                         '52c3a9fc-47a2-47c3-9bc4-8e788c47e7c1',
# ...

# %% [markdown]
# **What conclusions do you think we can take from this plots?**

# %%
#your conclusions here

#The distribution of heights is bimodal (due to reasons explained bellow) and so is the weight distribution, which makes sense sice this features are correlated;
#The distribution of ages is skewed to the to the right (due to reasons explained bellow);
#The BMI is redundant since is perfectly correlated with the height/weight**2;
#The BMI distribution is the one that shows more noticeble outliers but nothing too far off;

# %% [markdown]
# In addition to what the describe() method already told us we can see that the physical characteristics of the players (apart from the age) more or less follow a standard distribution, which is expected when looking at the distribution of values that arise from a lot of factors that are independent from each other as is the case for many physical quantities.
#
# The height distribution looks like a bimodal. This may be due to the fact that players in basketball fall under two main categories (please note that this is a very gross generalization): shorter and more agile, and taller and less agile. Therefore there are less "average" height players since they will neither be as agile as the shorter players nor have the same impact in the paint (that is, under the basket) as a taller player.
#
# The age distribution is a bit skewed to the right which is expected since most professional players stop playing after their prime physical years come to an end.

# %% [markdown]
# We could do the same for the main game stats. They are points, assists, blocks, rebounds and steals.
#
# **Now plot the distribution of the columns `REB`, `AST`, `STL`, `PTS` and `BLK` the same way you did in the last cell.**

# %%
wnba[['REB', 'AST', 'STL', 'BLK']].iplot(labels={'REB': 'Rebounds', 'AST': 'Assists', 'STL': 'Steals', 'BLK': 'Blocks'})
# Out:
# <div>
#
#
#             <div id="4d2bb53c-d2ad-4372-9937-8f5f86eafd73" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4d2bb53c-d2ad-4372-9937-8f5f86eafd73")) {
#                     Plotly.newPlot(
#                         '4d2bb53c-d2ad-4372-9937-8f5f86eafd73',
# ...

# %%
# Rebounds
wnba['REB'].iplot(kind='box', boxpoints='all', yTitle='Rebounds')
# Out:
# <div>
#
#
#             <div id="7020c0cf-230c-4cc0-a862-e9713e32b40f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("7020c0cf-230c-4cc0-a862-e9713e32b40f")) {
#                     Plotly.newPlot(
#                         '7020c0cf-230c-4cc0-a862-e9713e32b40f',
# ...

# %%
wnba['REB'].iplot(kind='hist',bins=20, xTitle='Rebounds', yTitle='Number of players')
# Out:
# <div>
#
#
#             <div id="a68663cc-e4f3-4ddd-875c-cace6560cac1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a68663cc-e4f3-4ddd-875c-cace6560cac1")) {
#                     Plotly.newPlot(
#                         'a68663cc-e4f3-4ddd-875c-cace6560cac1',
# ...

# %%
# Assists
wnba['AST'].iplot(kind='box', boxpoints='all', yTitle='Assists')
# Out:
# <div>
#
#
#             <div id="f7997684-bc5e-4b0d-870e-6af77758ec31" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f7997684-bc5e-4b0d-870e-6af77758ec31")) {
#                     Plotly.newPlot(
#                         'f7997684-bc5e-4b0d-870e-6af77758ec31',
# ...

# %%
wnba['AST'].iplot(kind='hist',bins=20, xTitle='Assists', yTitle='Number of players')
# Out:
# <div>
#
#
#             <div id="1a8ce4e1-897f-44e8-b18a-eea66522e30c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("1a8ce4e1-897f-44e8-b18a-eea66522e30c")) {
#                     Plotly.newPlot(
#                         '1a8ce4e1-897f-44e8-b18a-eea66522e30c',
# ...

# %%
# Steals
wnba['STL'].iplot(kind='box', boxpoints='all', yTitle='Steals')
# Out:
# <div>
#
#
#             <div id="0b183695-2547-4885-a63d-3dd5793a97ea" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0b183695-2547-4885-a63d-3dd5793a97ea")) {
#                     Plotly.newPlot(
#                         '0b183695-2547-4885-a63d-3dd5793a97ea',
# ...

# %%
wnba['STL'].iplot(kind='hist',bins=20, xTitle='Steals', yTitle='Number of players')
# Out:
# <div>
#
#
#             <div id="9816a4a4-a4b8-49f7-9ee1-64d1880f97a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9816a4a4-a4b8-49f7-9ee1-64d1880f97a9")) {
#                     Plotly.newPlot(
#                         '9816a4a4-a4b8-49f7-9ee1-64d1880f97a9',
# ...

# %%
# Total points
wnba['PTS'].iplot(kind='box', boxpoints='all', yTitle='Total points')
# Out:
# <div>
#
#
#             <div id="3bc35e3e-dfe2-4d6e-8120-20cca84f02b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3bc35e3e-dfe2-4d6e-8120-20cca84f02b6")) {
#                     Plotly.newPlot(
#                         '3bc35e3e-dfe2-4d6e-8120-20cca84f02b6',
# ...

# %%
wnba['PTS'].iplot(kind='hist',bins=20, xTitle='Total points', yTitle='Number of players')
# Out:
# <div>
#
#
#             <div id="5b3bdd2f-8822-4909-86f6-59d9dcc90e02" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5b3bdd2f-8822-4909-86f6-59d9dcc90e02")) {
#                     Plotly.newPlot(
#                         '5b3bdd2f-8822-4909-86f6-59d9dcc90e02',
# ...

# %%
# Blocks
wnba['BLK'].iplot(kind='box', boxpoints='all', yTitle='Blocks')
# Out:
# <div>
#
#
#             <div id="08ee6294-b8ee-49f4-896c-92620f83537b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("08ee6294-b8ee-49f4-896c-92620f83537b")) {
#                     Plotly.newPlot(
#                         '08ee6294-b8ee-49f4-896c-92620f83537b',
# ...

# %%
wnba['BLK'].iplot(kind='hist',bins=20, xTitle='Blocks', yTitle='Number of players')
# Out:
# <div>
#
#
#             <div id="982dbeb1-7daf-4a8a-8bd6-a70ccc5ac437" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("982dbeb1-7daf-4a8a-8bd6-a70ccc5ac437")) {
#                     Plotly.newPlot(
#                         '982dbeb1-7daf-4a8a-8bd6-a70ccc5ac437',
# ...

# %%
fig = px.scatter_matrix(wnba[['REB', 'AST', 'STL', 'BLK', 'MIN']])
fig.show()
# Out:
# <div>
#
#
#             <div id="373c460d-4ab9-42b2-8e49-8a5e1d9f3380" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("373c460d-4ab9-42b2-8e49-8a5e1d9f3380")) {
#                     Plotly.newPlot(
#                         '373c460d-4ab9-42b2-8e49-8a5e1d9f3380',
# ...

# %%
fig = px.scatter(data_frame=wnba, x='MIN', y='REB')
fig.show()
# Out:
# <div>
#
#
#             <div id="68f74578-24e3-4a48-986a-0da200f2eb72" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("68f74578-24e3-4a48-986a-0da200f2eb72")) {
#                     Plotly.newPlot(
#                         '68f74578-24e3-4a48-986a-0da200f2eb72',
# ...

# %%
fig = px.scatter(data_frame=wnba, x='MIN', y='AST')
fig.show()
# Out:
# <div>
#
#
#             <div id="839dab54-431b-4206-8f88-355dcaa0d4f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("839dab54-431b-4206-8f88-355dcaa0d4f4")) {
#                     Plotly.newPlot(
#                         '839dab54-431b-4206-8f88-355dcaa0d4f4',
# ...

# %%
fig = px.scatter(data_frame=wnba, x='MIN', y='STL')
fig.show()
# Out:
# <div>
#
#
#             <div id="dfb5e540-b6f8-43ff-bda3-11e82882b99c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dfb5e540-b6f8-43ff-bda3-11e82882b99c")) {
#                     Plotly.newPlot(
#                         'dfb5e540-b6f8-43ff-bda3-11e82882b99c',
# ...

# %%
fig = px.scatter(data_frame=wnba, x='MIN', y='BLK')
fig.show()
# Out:
# <div>
#
#
#             <div id="27e8f57a-22bd-484e-96fc-f0cfcca27080" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("27e8f57a-22bd-484e-96fc-f0cfcca27080")) {
#                     Plotly.newPlot(
#                         '27e8f57a-22bd-484e-96fc-f0cfcca27080',
# ...

# %% [markdown]
# **What conclusions do you think we can take from this plots?**

# %%
#your conclusions here
# All the distributions are skewed to the left because a lot of the players have stats close to 
# zero due to the low number of minutes played

# %% [markdown]
# As expected all of the above distribution are heavily skewed to the left, since most players will have very low to average stats while there will be a handful of star players whose stats peak above everyone else. It is also important to think about the fact that we are simply taking the stats as they are without considering the minutes played by each player. Even though skill plays a very important factor in determining this kind of stats we also have to consider that players that play more minutes will, on average, score more points (or blocks, assists, etc.).

# %% [markdown]
# **For the sake of it let's look at the same distributions by dividing those stats by the minutes played for each player in the dataset.**

# %%
#your code here
wnba['MIN'].iplot(kind='hist',bins=50, xTitle='Minutes Played', yTitle='Number of players')
# Out:
# <div>
#
#
#             <div id="ac5f9203-c86b-49d5-8531-84537fc67548" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ac5f9203-c86b-49d5-8531-84537fc67548")) {
#                     Plotly.newPlot(
#                         'ac5f9203-c86b-49d5-8531-84537fc67548',
# ...

# %%
# Total rebounds by minute
reb_min = wnba['REB']/wnba['MIN']
reb_min.iplot(kind='hist',bins=25, xTitle='Rebounds by minute', yTitle='Number of players')
# Out:
# <div>
#
#
#             <div id="ae8031bc-75e5-42c1-bc85-cef7e8d217a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ae8031bc-75e5-42c1-bc85-cef7e8d217a4")) {
#                     Plotly.newPlot(
#                         'ae8031bc-75e5-42c1-bc85-cef7e8d217a4',
# ...

# %%
# Assists by minute
ast_min = wnba['AST']/wnba['MIN']
ast_min.iplot(kind='hist',bins=50, xTitle='Assists by minute', yTitle='Number of players')
# Out:
# <div>
#
#
#             <div id="3eee5ccc-4613-4432-979c-d0868c917e4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3eee5ccc-4613-4432-979c-d0868c917e4f")) {
#                     Plotly.newPlot(
#                         '3eee5ccc-4613-4432-979c-d0868c917e4f',
# ...

# %%
# Assists by minute
ast_min = wnba['AST']/wnba['MIN']
ast_min.iplot(kind='hist',bins=50, xTitle='Assists by minute', yTitle='Number of players')
# Out:
# <div>
#
#
#             <div id="e2d4af27-d62a-41fe-ba84-f4c2abe32738" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("e2d4af27-d62a-41fe-ba84-f4c2abe32738")) {
#                     Plotly.newPlot(
#                         'e2d4af27-d62a-41fe-ba84-f4c2abe32738',
# ...

# %%
wnba.dtypes

# %% [markdown]
# **What conclusions do you think we can take from this plots?**

# %%
#your conclusions here

# %% [markdown]
# ### Summary
#
# The main insights we obtained from this exploratory analysis are:
# - Game-related stats have a very high range of values.
# - There are some extremes in the weight and age columns.
# - The physical characteristics of the players more or less follow a standard distribution.
# - We need to take into account that our dataset contains data on both players that play the majority of games and also players that may spend almost the entirety of the season on the bench.
#
# Now, it's time to try to put an end to your family's discussions. As seen on the README, the main discussions are:
# - Your grandmother says that your sister couldn't play in a professional basketball league (not only the WNBA, but ANY professional basketball league) because she's too skinny and lacks muscle.
# - Your sister says that most female professional players fail their free throws.
# - Your brother-in-law heard on the TV that the average assists among NBA (male) and WNBA (female) players is 52 for the 2016-2017 season. He is convinced this average would be higher if we only considered the players from the WNBA.
#
# **Do you think you have all the necessary data to answer these questions?**

# %%
#your comments here
