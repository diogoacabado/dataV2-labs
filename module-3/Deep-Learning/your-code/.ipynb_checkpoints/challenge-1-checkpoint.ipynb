# %% [markdown]
# # Challenge 1 - Tic Tac Toe
#
# In this lab you will perform deep learning analysis on a dataset of playing [Tic Tac Toe](https://en.wikipedia.org/wiki/Tic-tac-toe).
#
# There are 9 grids in Tic Tac Toe that are coded as the following picture shows:
#
# ![Tic Tac Toe Grids](tttboard.jpg)
#
# In the first 9 columns of the dataset you can find which marks (`x` or `o`) exist in the grids. If there is no mark in a certain grid, it is labeled as `b`. The last column is `class` which tells you whether Player X (who always moves first in Tic Tac Toe) wins in this configuration. Note that when `class` has the value `False`, it means either Player O wins the game or it ends up as a draw.

# %% [markdown]
# Follow the steps suggested below to conduct a neural network analysis using Tensorflow and Keras. You will build a deep learning model to predict whether Player X wins the game or not.
#
# ## Step 1: Data Engineering
#
# This dataset is almost in the ready-to-use state so you do not need to worry about missing values and so on. Still, some simple data engineering is needed.
#
# 1. Read `tic-tac-toe.csv` into a dataframe.
# 1. Inspect the dataset. Determine if the dataset is reliable by eyeballing the data.
# 1. Convert the categorical values to numeric in all columns.
# 1. Separate the inputs and output.
# 1. Normalize the input data.

# %%
# your code here
import pandas as pd

df = pd.read_csv('tic-tac-toe.csv')

df.head()
# Out:
#   TL TM TR ML MM MR BL BM BR  class
# 0  x  x  x  x  o  o  x  o  o   True
# 1  x  x  x  x  o  o  o  x  o   True
# 2  x  x  x  x  o  o  o  o  x   True
# 3  x  x  x  x  o  o  o  b  b   True
# 4  x  x  x  x  o  o  b  o  b   True

# %%
df.isna().sum()
# Out:
# TL       0
# TM       0
# TR       0
# ML       0
# MM       0
# MR       0
# BL       0
# BM       0
# BR       0
# class    0
# dtype: int64

# %%
df.shape
# Out:
# (958, 10)

# %%
df.replace(to_replace=['x', 'o', 'b'], value=[1, 2, 0], inplace=True)

df.head()
# Out:
#    TL  TM  TR  ML  MM  MR  BL  BM  BR  class
# 0   1   1   1   1   2   2   1   2   2   True
# 1   1   1   1   1   2   2   2   1   2   True
# 2   1   1   1   1   2   2   2   2   1   True
# 3   1   1   1   1   2   2   2   0   0   True
# 4   1   1   1   1   2   2   0   2   0   True

# %%
df['class'] = df['class'].apply(lambda x: 1 if x else 0)

# %%
df.head()
# Out:
#    TL  TM  TR  ML  MM  MR  BL  BM  BR  class
# 0   1   1   1   1   2   2   1   2   2      1
# 1   1   1   1   1   2   2   2   1   2      1
# 2   1   1   1   1   2   2   2   2   1      1
# 3   1   1   1   1   2   2   2   0   0      1
# 4   1   1   1   1   2   2   0   2   0      1

# %%
df.dtypes
# Out:
# TL       int64
# TM       int64
# TR       int64
# ML       int64
# MM       int64
# MR       int64
# BL       int64
# BM       int64
# BR       int64
# class    int64
# dtype: object

# %%
X = df.drop(columns='class').values
y = df['class'].values

# %%
#X = X.astype(float)
#y = y.astype(float)

# %%
from tensorflow.keras.utils import normalize

X = normalize(X, axis=1)

# %% [markdown]
# ## Step 2: Build Neural Network
#
# To build the neural network, you can refer to your own codes you wrote while following the [Deep Learning with Python, TensorFlow, and Keras tutorial](https://www.youtube.com/watch?v=wQ8BIBpya2k) in the lesson. It's pretty similar to what you will be doing in this lab.
#
# 1. Split the training and test data.
# 1. Create a `Sequential` model.
# 1. Add several layers to your model. Make sure you use ReLU as the activation function for the middle layers. Use Softmax for the output layer because each output has a single lable and all the label probabilities add up to 1.
# 1. Compile the model using `adam` as the optimizer and `sparse_categorical_crossentropy` as the loss function. For metrics, use `accuracy` for now.
# 1. Fit the training data.
# 1. Evaluate your neural network model with the test data.
# 1. Save your model as `tic-tac-toe.model`.

# %%
# your code here
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
# array([[0.25      , 0.        , 0.25      , ..., 0.25      , 0.        ,
#         0.5       ],
#        [0.43643578, 0.21821789, 0.43643578, ..., 0.43643578, 0.21821789,
#         0.43643578],
#        [0.25819889, 0.        , 0.25819889, ..., 0.51639778, 0.51639778,
#         0.51639778],
#        ...,
#        [0.51639778, 0.        , 0.25819889, ..., 0.51639778, 0.        ,
#         0.25819889],
#        [0.5       , 0.        , 0.25      , ..., 0.25      , 0.        ,
#         0.25      ],
#        [0.25      , 0.25      , 0.        , ..., 0.25      , 0.        ,
#         0.5       ]])

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# model = tf.keras.models.Sequential()
# model.add(tf.keras.layers.Flatten())
# model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
# model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
# model.add(tf.keras.layers.Dense(3, activation=tf.nn.softmax))
# model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# model.fit(X_train, y_train, epochs=90)

# %%
model = Sequential()

model.add(Dense(units=100, activation='relu'))

model.add(Dense(units=50, activation='relu'))

model.add(Dense(units=3, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics =['accuracy'])

# %%
model.fit(x=X_train, y=y_train, epochs=100, validation_data=(X_test, y_test))
# Out:
# Train on 670 samples, validate on 288 samples
# Epoch 1/100
# 670/670 [==============================] - 0s 511us/sample - loss: 1.0012 - accuracy: 0.5612 - val_loss: 0.8747 - val_accuracy: 0.6701
# Epoch 2/100
# 670/670 [==============================] - 0s 59us/sample - loss: 0.7985 - accuracy: 0.6463 - val_loss: 0.7064 - val_accuracy: 0.6701
# Epoch 3/100
# 670/670 [==============================] - 0s 63us/sample - loss: 0.6813 - accuracy: 0.6463 - val_loss: 0.6402 - val_accuracy: 0.6701
# Epoch 4/100
# 670/670 [==============================] - 0s 61us/sample - loss: 0.6428 - accuracy: 0.6478 - val_loss: 0.6186 - val_accuracy: 0.6771
# Epoch 5/100
# 670/670 [==============================] - 0s 62us/sample - loss: 0.6257 - accuracy: 0.6552 - val_loss: 0.6071 - val_accuracy: 0.6667
# Epoch 6/100
# 670/670 [==============================] - 0s 59us/sample - loss: 0.6133 - accuracy: 0.6507 - val_loss: 0.6033 - val_accuracy: 0.6701
# Epoch 7/100
# 670/670 [==============================] - 0s 61us/sample - loss: 0.6044 - accuracy: 0.6627 - val_loss: 0.6014 - val_accuracy: 0.6840
# Epoch 8/100
# 670/670 [==============================] - 0s 71us/sample - loss: 0.5975 - accuracy: 0.6791 - val_loss: 0.5827 - val_accuracy: 0.6771
# Epoch 9/100
# 670/670 [==============================] - 0s 63us/sample - loss: 0.5841 - accuracy: 0.6761 - val_loss: 0.5753 - val_accuracy: 0.6701
# Epoch 10/100
# 670/670 [==============================] - 0s 57us/sample - loss: 0.5750 - accuracy: 0.6881 - val_loss: 0.5673 - val_accuracy: 0.6910
# Epoch 11/100
# Epoch 93/100
# 670/670 [==============================] - 0s 59us/sample - loss: 0.2270 - accuracy: 0.9060 - val_loss: 0.3769 - val_accuracy: 0.8160
# Epoch 94/100
# 670/670 [==============================] - 0s 59us/sample - loss: 0.2192 - accuracy: 0.9164 - val_loss: 0.3784 - val_accuracy: 0.8194
# Epoch 95/100
# 670/670 [==============================] - 0s 59us/sample - loss: 0.2170 - accuracy: 0.9164 - val_loss: 0.3768 - val_accuracy: 0.8194
# Epoch 96/100
# 670/670 [==============================] - 0s 57us/sample - loss: 0.2136 - accuracy: 0.9209 - val_loss: 0.3732 - val_accuracy: 0.8160
# Epoch 97/100
# 670/670 [==============================] - 0s 58us/sample - loss: 0.2155 - accuracy: 0.9269 - val_loss: 0.3592 - val_accuracy: 0.8229
# Epoch 98/100
# 670/670 [==============================] - 0s 57us/sample - loss: 0.2101 - accuracy: 0.9209 - val_loss: 0.3617 - val_accuracy: 0.8229
# Epoch 99/100
# 670/670 [==============================] - 0s 55us/sample - loss: 0.2136 - accuracy: 0.9179 - val_loss: 0.3795 - val_accuracy: 0.8229
# Epoch 100/100
# 670/670 [==============================] - 0s 57us/sample - loss: 0.2080 - accuracy: 0.9149 - val_loss: 0.3586 - val_accuracy: 0.8299

# %%
loss_df = pd.DataFrame(model.history.history)

# %%
loss_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.001217  0.561194  0.874745      0.670139
# 1   0.798478  0.646269  0.706370      0.670139
# 2   0.681290  0.646269  0.640205      0.670139
# 3   0.642844  0.647761  0.618627      0.677083
# 4   0.625702  0.655224  0.607115      0.666667
# ..       ...       ...       ...           ...
# 95  0.213605  0.920896  0.373245      0.815972
# 96  0.215498  0.926866  0.359188      0.822917
# 97  0.210113  0.920896  0.361662      0.822917
# 98  0.213602  0.917910  0.379466      0.822917
# 99  0.208010  0.914925  0.358648      0.829861
#
# [100 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

epochs = list(loss_df.index)
loss = list(loss_df['loss'])
val_loss = list(loss_df['val_loss'])

plt.style.use('fivethirtyeight')

plt.figure(figsize=(12,6))

plt.plot(epochs, loss, linewidth=3, label='Training data')

plt.plot(epochs, val_loss, linewidth=3, label='Test data')

plt.title('Loss function vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.legend()

plt.tight_layout()

plt.show()

# %%
model.save('tic-tac-toe.model')
# Out:
# WARNING:tensorflow:From /Users/diogoacabado/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: tic-tac-toe.model/assets

# %%
import numpy as np

# evaluate the model
cvscores = []

scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
cvscores.append(scores[1] * 100)
# Out:
# accuracy: 82.99%

# %% [markdown]
# ## Step 3: Make Predictions
#
# Now load your saved model and use it to make predictions on a few random rows in the test dataset. Check if the predictions are correct.

# %%
from tensorflow.keras.models import load_model

# %%
# your code here
model = load_model('tic-tac-toe.model')

# %%
pred = model.predict(X_test)

# %% [markdown]
# ## Step 4: Improve Your Model
#
# Did your model achieve low loss (<0.1) and high accuracy (>0.95)? If not, try to improve your model.
#
# But how? There are so many things you can play with in Tensorflow and in the next challenge you'll learn about these things. But in this challenge, let's just do a few things to see if they will help.
#
# * Add more layers to your model. If the data are complex you need more layers. But don't use more layers than you need. If adding more layers does not improve the model performance you don't need additional layers.
# * Adjust the learning rate when you compile the model. This means you will create a custom `tf.keras.optimizers.Adam` instance where you specify the learning rate you want. Then pass the instance to `model.compile` as the optimizer.
#     * `tf.keras.optimizers.Adam` [reference](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam).
#     * Don't worry if you don't understand what the learning rate does. You'll learn about it in the next challenge.
# * Adjust the number of epochs when you fit the training data to the model. Your model performance continues to improve as you train more epochs. But eventually it will reach the ceiling and the performance will stay the same.

# %%
from tensorflow.keras import optimizers

# %%
# your code here
adam_opt = optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07, amsgrad=False, name='Adam')

# %%
model = Sequential()

model.add(Dense(units=100, activation='relu'))

model.add(Dense(units=50, activation='relu'))

model.add(Dense(units=25, activation='relu'))

model.add(Dense(units=12, activation='relu'))

model.add(Dense(units=6, activation='relu'))

model.add(Dense(units=3, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer=adam_opt, metrics =['accuracy'])

# %%
model.fit(x=X_train, y=y_train, epochs=100, validation_data=(X_test, y_test))
# Out:
# Train on 670 samples, validate on 288 samples
# Epoch 1/100
# 670/670 [==============================] - 0s 614us/sample - loss: 0.9860 - accuracy: 0.3537 - val_loss: 0.8840 - val_accuracy: 0.3299
# Epoch 2/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.8153 - accuracy: 0.3537 - val_loss: 0.7521 - val_accuracy: 0.3299
# Epoch 3/100
# 670/670 [==============================] - 0s 73us/sample - loss: 0.6967 - accuracy: 0.5567 - val_loss: 0.6480 - val_accuracy: 0.6701
# Epoch 4/100
# 670/670 [==============================] - 0s 62us/sample - loss: 0.6568 - accuracy: 0.6463 - val_loss: 0.6375 - val_accuracy: 0.6701
# Epoch 5/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.6523 - accuracy: 0.6463 - val_loss: 0.6411 - val_accuracy: 0.6701
# Epoch 6/100
# 670/670 [==============================] - 0s 63us/sample - loss: 0.6487 - accuracy: 0.6463 - val_loss: 0.6337 - val_accuracy: 0.6701
# Epoch 7/100
# 670/670 [==============================] - 0s 68us/sample - loss: 0.6470 - accuracy: 0.6463 - val_loss: 0.6312 - val_accuracy: 0.6701
# Epoch 8/100
# 670/670 [==============================] - 0s 72us/sample - loss: 0.6429 - accuracy: 0.6463 - val_loss: 0.6290 - val_accuracy: 0.6701
# Epoch 9/100
# 670/670 [==============================] - 0s 76us/sample - loss: 0.6394 - accuracy: 0.6463 - val_loss: 0.6246 - val_accuracy: 0.6701
# Epoch 10/100
# 670/670 [==============================] - 0s 69us/sample - loss: 0.6335 - accuracy: 0.6463 - val_loss: 0.6219 - val_accuracy: 0.6701
# Epoch 11/100
# 670/670 [==============================] - 0s 74us/sample - loss: 0.6269 - accuracy: 0.6463 - val_loss: 0.6136 - val_accuracy: 0.6701
# Epoch 12/100
# 670/670 [==============================] - 0s 72us/sample - loss: 0.6223 - accuracy: 0.6463 - val_loss: 0.6062 - val_accuracy: 0.6701
# Epoch 13/100
# 670/670 [==============================] - 0s 70us/sample - loss: 0.6106 - accuracy: 0.6448 - val_loss: 0.5974 - val_accuracy: 0.6736
# Epoch 14/100
# 670/670 [==============================] - 0s 68us/sample - loss: 0.6059 - accuracy: 0.6582 - val_loss: 0.6016 - val_accuracy: 0.6424
# Epoch 15/100
# 670/670 [==============================] - 0s 70us/sample - loss: 0.5913 - accuracy: 0.6851 - val_loss: 0.5794 - val_accuracy: 0.6701
# Epoch 16/100
# 670/670 [==============================] - 0s 72us/sample - loss: 0.3228 - accuracy: 0.8612 - val_loss: 0.3985 - val_accuracy: 0.7986
# Epoch 37/100
# 670/670 [==============================] - 0s 71us/sample - loss: 0.3008 - accuracy: 0.8687 - val_loss: 0.4094 - val_accuracy: 0.8056
# Epoch 38/100
# 670/670 [==============================] - 0s 67us/sample - loss: 0.3063 - accuracy: 0.8716 - val_loss: 0.3974 - val_accuracy: 0.7847
# Epoch 39/100
# 670/670 [==============================] - 0s 62us/sample - loss: 0.2972 - accuracy: 0.8761 - val_loss: 0.3909 - val_accuracy: 0.8125
# Epoch 40/100
# 670/670 [==============================] - 0s 62us/sample - loss: 0.2968 - accuracy: 0.8687 - val_loss: 0.4302 - val_accuracy: 0.7674
# Epoch 41/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.2977 - accuracy: 0.8776 - val_loss: 0.3775 - val_accuracy: 0.8160
# Epoch 42/100
# 670/670 [==============================] - 0s 63us/sample - loss: 0.2786 - accuracy: 0.8806 - val_loss: 0.3871 - val_accuracy: 0.8090
# Epoch 43/100
# 670/670 [==============================] - 0s 60us/sample - loss: 0.2664 - accuracy: 0.8910 - val_loss: 0.4094 - val_accuracy: 0.7778
# Epoch 44/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.2931 - accuracy: 0.8836 - val_loss: 0.3967 - val_accuracy: 0.8160
# Epoch 45/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.2533 - accuracy: 0.8940 - val_loss: 0.4305 - val_accuracy: 0.7639
# Epoch 46/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.2586 - accuracy: 0.8970 - val_loss: 0.3823 - val_accuracy: 0.7986
# Epoch 47/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.2463 - accuracy: 0.8896 - val_loss: 0.3777 - val_accuracy: 0.8194
# Epoch 48/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.2335 - accuracy: 0.9000 - val_loss: 0.3863 - val_accuracy: 0.8264
# Epoch 49/100
# 670/670 [==============================] - 0s 62us/sample - loss: 0.2333 - accuracy: 0.9045 - val_loss: 0.3881 - val_accuracy: 0.8125
# Epoch 50/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.2423 - accuracy: 0.9030 - val_loss: 0.3768 - val_accuracy: 0.8368
# Epoch 51/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.2278 - accuracy: 0.9030 - val_loss: 0.3752 - val_accuracy: 0.8090
# Epoch 52/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.2220 - accuracy: 0.9164 - val_loss: 0.3959 - val_accuracy: 0.8438
# Epoch 53/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.2295 - accuracy: 0.9075 - val_loss: 0.3963 - val_accuracy: 0.8194
# Epoch 54/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.2376 - accuracy: 0.8985 - val_loss: 0.3714 - val_accuracy: 0.8438
# Epoch 55/100
# 670/670 [==============================] - 0s 65us/sample - loss: 0.2126 - accuracy: 0.9164 - val_loss: 0.3841 - val_accuracy: 0.8299
# Epoch 56/100
# 670/670 [==============================] - 0s 69us/sample - loss: 0.2175 - accuracy: 0.9090 - val_loss: 0.4008 - val_accuracy: 0.8333
# Epoch 57/100
# 670/670 [==============================] - 0s 61us/sample - loss: 0.2262 - accuracy: 0.9030 - val_loss: 0.3664 - val_accuracy: 0.8194
# Epoch 58/100
# 670/670 [==============================] - 0s 65us/sample - loss: 0.1925 - accuracy: 0.9284 - val_loss: 0.3774 - val_accuracy: 0.8333
# Epoch 59/100
# 670/670 [==============================] - 0s 63us/sample - loss: 0.1906 - accuracy: 0.9179 - val_loss: 0.3652 - val_accuracy: 0.8264
# Epoch 60/100
# 670/670 [==============================] - 0s 63us/sample - loss: 0.1980 - accuracy: 0.9224 - val_loss: 0.3928 - val_accuracy: 0.8299
# Epoch 61/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.1920 - accuracy: 0.9269 - val_loss: 0.3763 - val_accuracy: 0.8333
# Epoch 62/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.1985 - accuracy: 0.9194 - val_loss: 0.3812 - val_accuracy: 0.8160
# Epoch 63/100
# 670/670 [==============================] - 0s 68us/sample - loss: 0.1889 - accuracy: 0.9269 - val_loss: 0.3925 - val_accuracy: 0.8160
# Epoch 64/100
# 670/670 [==============================] - 0s 68us/sample - loss: 0.1728 - accuracy: 0.9358 - val_loss: 0.3794 - val_accuracy: 0.8194
# Epoch 65/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.1878 - accuracy: 0.9209 - val_loss: 0.4020 - val_accuracy: 0.8333
# Epoch 66/100
# 670/670 [==============================] - 0s 63us/sample - loss: 0.1742 - accuracy: 0.9254 - val_loss: 0.3799 - val_accuracy: 0.8299
# Epoch 67/100
# 670/670 [==============================] - 0s 67us/sample - loss: 0.1656 - accuracy: 0.9284 - val_loss: 0.3734 - val_accuracy: 0.8229
# Epoch 68/100
# 670/670 [==============================] - 0s 66us/sample - loss: 0.1566 - accuracy: 0.9418 - val_loss: 0.3728 - val_accuracy: 0.8299
# Epoch 69/100
# 670/670 [==============================] - 0s 65us/sample - loss: 0.1600 - accuracy: 0.9358 - val_loss: 0.3722 - val_accuracy: 0.8333
# Epoch 70/100
# 670/670 [==============================] - 0s 67us/sample - loss: 0.1485 - accuracy: 0.9418 - val_loss: 0.3895 - val_accuracy: 0.8507
# Epoch 71/100
# 670/670 [==============================] - 0s 63us/sample - loss: 0.1471 - accuracy: 0.9373 - val_loss: 0.3720 - val_accuracy: 0.8194
# Epoch 72/100
# 670/670 [==============================] - 0s 66us/sample - loss: 0.1407 - accuracy: 0.9463 - val_loss: 0.3883 - val_accuracy: 0.8368
# Epoch 73/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.1313 - accuracy: 0.9552 - val_loss: 0.3846 - val_accuracy: 0.8507
# Epoch 74/100
# 670/670 [==============================] - 0s 66us/sample - loss: 0.1302 - accuracy: 0.9448 - val_loss: 0.4477 - val_accuracy: 0.8438
# Epoch 75/100
# 670/670 [==============================] - 0s 63us/sample - loss: 0.1468 - accuracy: 0.9448 - val_loss: 0.4297 - val_accuracy: 0.8125
# Epoch 76/100
# 670/670 [==============================] - 0s 67us/sample - loss: 0.1931 - accuracy: 0.9269 - val_loss: 0.4411 - val_accuracy: 0.8299
# Epoch 77/100
# 670/670 [==============================] - 0s 67us/sample - loss: 0.1561 - accuracy: 0.9358 - val_loss: 0.4004 - val_accuracy: 0.8438
# Epoch 78/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.1261 - accuracy: 0.9493 - val_loss: 0.3963 - val_accuracy: 0.8194
# Epoch 79/100
# 670/670 [==============================] - 0s 76us/sample - loss: 0.1259 - accuracy: 0.9597 - val_loss: 0.3598 - val_accuracy: 0.8507
# Epoch 80/100
# 670/670 [==============================] - 0s 65us/sample - loss: 0.1173 - accuracy: 0.9493 - val_loss: 0.3966 - val_accuracy: 0.8368
# Epoch 81/100
# 670/670 [==============================] - 0s 65us/sample - loss: 0.1176 - accuracy: 0.9507 - val_loss: 0.3702 - val_accuracy: 0.8507
# Epoch 82/100
# 670/670 [==============================] - 0s 63us/sample - loss: 0.1101 - accuracy: 0.9552 - val_loss: 0.3860 - val_accuracy: 0.8299
# Epoch 83/100
# 670/670 [==============================] - 0s 66us/sample - loss: 0.1122 - accuracy: 0.9507 - val_loss: 0.3743 - val_accuracy: 0.8507
# Epoch 84/100
# 670/670 [==============================] - 0s 62us/sample - loss: 0.0968 - accuracy: 0.9612 - val_loss: 0.3733 - val_accuracy: 0.8403
# Epoch 85/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.1013 - accuracy: 0.9597 - val_loss: 0.4250 - val_accuracy: 0.8542
# Epoch 86/100
# 670/670 [==============================] - 0s 66us/sample - loss: 0.1154 - accuracy: 0.9493 - val_loss: 0.3760 - val_accuracy: 0.8438
# Epoch 87/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.0934 - accuracy: 0.9612 - val_loss: 0.3974 - val_accuracy: 0.8646
# Epoch 88/100
# 670/670 [==============================] - 0s 62us/sample - loss: 0.0932 - accuracy: 0.9672 - val_loss: 0.3808 - val_accuracy: 0.8542
# Epoch 89/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.0929 - accuracy: 0.9657 - val_loss: 0.3890 - val_accuracy: 0.8576
# Epoch 90/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.0874 - accuracy: 0.9672 - val_loss: 0.3979 - val_accuracy: 0.8438
# Epoch 91/100
# 670/670 [==============================] - 0s 65us/sample - loss: 0.0885 - accuracy: 0.9672 - val_loss: 0.4120 - val_accuracy: 0.8299
# Epoch 92/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.0784 - accuracy: 0.9731 - val_loss: 0.4886 - val_accuracy: 0.8438
# Epoch 93/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.0858 - accuracy: 0.9672 - val_loss: 0.4022 - val_accuracy: 0.8403
# Epoch 94/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.0710 - accuracy: 0.9701 - val_loss: 0.4021 - val_accuracy: 0.8542
# Epoch 95/100
# 670/670 [==============================] - 0s 65us/sample - loss: 0.0715 - accuracy: 0.9701 - val_loss: 0.3895 - val_accuracy: 0.8472
# Epoch 96/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.0709 - accuracy: 0.9731 - val_loss: 0.4028 - val_accuracy: 0.8542
# Epoch 97/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.0728 - accuracy: 0.9761 - val_loss: 0.4576 - val_accuracy: 0.8299
# Epoch 98/100
# 670/670 [==============================] - 0s 64us/sample - loss: 0.0662 - accuracy: 0.9761 - val_loss: 0.4004 - val_accuracy: 0.8472
# Epoch 99/100
# 670/670 [==============================] - 0s 63us/sample - loss: 0.0622 - accuracy: 0.9806 - val_loss: 0.4246 - val_accuracy: 0.8403
# Epoch 100/100
# 670/670 [==============================] - 0s 65us/sample - loss: 0.0649 - accuracy: 0.9776 - val_loss: 0.3994 - val_accuracy: 0.8507

# %%
loss_df = pd.DataFrame(model.history.history)

# %%
epochs = list(loss_df.index)
loss = list(loss_df['loss'])
val_loss = list(loss_df['val_loss'])

plt.style.use('fivethirtyeight')

plt.figure(figsize=(12,6))

plt.plot(epochs, loss, linewidth=3, label='Training data')

plt.plot(epochs, val_loss, linewidth=3, label='Test data')

plt.title('Loss function vs Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.legend()

plt.tight_layout()

plt.show()

# %%
# evaluate the model
cvscores = []

scores = model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
cvscores.append(scores[1] * 100)
# Out:
# accuracy: 85.07%

# %% [markdown]
# **Which approach(es) did you find helpful to improve your model performance?**

# %%
# I added 3 more lairs and used adam optimizer to raise the accuracy score from 83 to 85%
