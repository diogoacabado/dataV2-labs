# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
from stackapi import StackAPI
SITE = StackAPI('stackoverflow')

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# your code here
questions = SITE.fetch('questions', fromdate=1580515200, todate=1583020799)

# %%
questions['items'][0]
# Out:
# {'tags': ['python', 'tensorflow', 'keras', 'pre-trained-model'],
#  'owner': {'reputation': 2139,
#   'user_id': 3337089,
#   'user_type': 'registered',
#   'accept_rate': 86,
#   'profile_image': 'https://www.gravatar.com/avatar/b096725512960a65abe37b76c383de67?s=128&d=identicon&r=PG&f=1',
#   'display_name': 'Nagabhushan S N',
#   'link': 'https://stackoverflow.com/users/3337089/nagabhushan-s-n'},
#  'is_answered': True,
#  'view_count': 26,
#  'answer_count': 1,
#  'score': 5,
#  'last_activity_date': 1583723188,
#  'creation_date': 1583716704,
#  'question_id': 60593624,
#  'link': 'https://stackoverflow.com/questions/60593624/modify-trained-model-architecture-and-continue-training-keras',
#  'title': 'Modify trained model architecture and continue training Keras'}

# %%
quest = pd.DataFrame(questions['items'])

# %%
quest
# Out:
#                                                   tags  \
# 0       [python, tensorflow, keras, pre-trained-model]
# 1                                     [python, pandas]
# 2                                       [python, list]
# 3                          [python, pandas, dataframe]
# 4             [python, regex, pandas, dataframe, nltk]
# ..                                                 ...
# 495           [python, firebase-cloud-messaging, mule]
# 496    [python, android, flask, heroku, flask-restful]
# 497  [python, tensorflow, tensorflow2.0, image-reco...
# 498                                     [python, math]
# 499                           [python, html, selenium]
#
#                                                  owner  is_answered  \
# 0    {'reputation': 2139, 'user_id': 3337089, 'user...         True
# 1    {'reputation': 139, 'user_id': 10783924, 'user...         True
# 2    {'reputation': 41, 'user_id': 13032963, 'user_...         True
# 3    {'reputation': 43, 'user_id': 13032899, 'user_...         True
# 4    {'reputation': 612, 'user_id': 9161067, 'user_...         True
# ..                                                 ...          ...
# 495  {'reputation': 11, 'user_id': 12852541, 'user_...        False
# 496  {'reputation': 517, 'user_id': 726872, 'user_t...        False
# 497  {'reputation': 53, 'user_id': 6095520, 'user_t...        False
# 498  {'reputation': 1, 'user_id': 12823073, 'user_t...        False
# 499  {'reputation': 7, 'user_id': 12438012, 'user_t...        False
#
#      view_count  answer_count  score  last_activity_date  creation_date  \
# 0            26             1      5          1583723188     1583716704
# 1            59             4      4          1583724631     1583723323
# 2            40             2      4          1583760265     1583759138
# 3            21             2      4          1583760641     1583759591
# 4            59             1      4          1583769158     1583764083
# ..          ...           ...    ...                 ...            ...
# 495          18             1      0          1583780242     1583758761
# 496          26             0      0          1583771337     1583758716
# 497          12             0      0          1583758534     1583758534
# 498           5             0      0          1583758638     1583758318
# 499          19             0      0          1583759560     1583758075
#
#      question_id                                               link  \
# 0       60593624  https://stackoverflow.com/questions/60593624/m...
# 1       60594272  https://stackoverflow.com/questions/60594272/f...
# 2       60601208  https://stackoverflow.com/questions/60601208/h...
# 3       60601337  https://stackoverflow.com/questions/60601337/g...
# 4       60602630  https://stackoverflow.com/questions/60602630/p...
# ..           ...                                                ...
# 495     60601096  https://stackoverflow.com/questions/60601096/m...
# 496     60601079  https://stackoverflow.com/questions/60601079/f...
# 497     60601026  https://stackoverflow.com/questions/60601026/t...
# 498     60600964  https://stackoverflow.com/questions/60600964/m...
# 499     60600900  https://stackoverflow.com/questions/60600900/p...
#
#                                                  title  accepted_answer_id  \
# 0    Modify trained model architecture and continue...                 NaN
# 1    Find row average of tuples in data frame / 2d ...          60594311.0
# 2    How do I make independent lists within in a list?                 NaN
# 3    groupby and withhold information of one column...          60601542.0
# 4    Partial keyword match not working when I am tr...          60604053.0
# ..                                                 ...                 ...
# 495  Mule 3.8 error: ImportError: No module named auth                 NaN
# 496  flask-restful HTTP 500 when uploading file fro...                 NaN
# 497     Tensorflow For Poets - Upgrade to Tensorflow 2                 NaN
# 498                           Mathpix - Image Retrieve                 NaN
# 499  Python3 Scraping Printer`s web page is not wor...                 NaN
#
#      last_edit_date  closed_date closed_reason
# 0               NaN          NaN           NaN
# 1      1.583724e+09          NaN           NaN
# 2      1.583760e+09          NaN           NaN
# 3      1.583760e+09          NaN           NaN
# 4      1.583767e+09          NaN           NaN
# ..              ...          ...           ...
# 495    1.583760e+09          NaN           NaN
# 496    1.583771e+09          NaN           NaN
# 497             NaN          NaN           NaN
# 498    1.583759e+09          NaN           NaN
# 499    1.583760e+09          NaN           NaN
#
# [500 rows x 15 columns]

# %%
answers = SITE.fetch('answers', fromdate=1580515200, todate=1583020799)

# %%
answ = pd.DataFrame(answers['items'])

# %%
answ.head()
# Out:
#                                                owner  is_accepted  score  \
# 0  {'reputation': 2340, 'user_id': 2233308, 'user...        False      1
# 1  {'reputation': 10120, 'user_id': 4728685, 'use...        False      0
# 2  {'reputation': 1085, 'user_id': 1726544, 'user...         True      0
# 3  {'reputation': 731, 'user_id': 1131162, 'user_...         True      0
# 4  {'reputation': 8869, 'user_id': 361855, 'user_...        False      0
#
#    last_activity_date  last_edit_date  creation_date  answer_id  question_id  \
# 0          1583780299      1583780299     1581760398   60237619     60233772
# 1          1583778673      1583778673     1581930701   60259073     60258429
# 2          1583776164      1583776164     1582124343   60303161     60270123
# 3          1583775364      1583775364     1582481478   60365300     60287191
# 4          1583775201      1583775201     1582755304   60423420     58675893
#
#    community_owned_date
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here

questions = SITE.fetch('questions', fromdate=1583712000, todate=1583785860,
    tagged='python', sort='votes')

# %%
questions['items'][0]
# Out:
# {'tags': ['python', 'tensorflow', 'keras', 'pre-trained-model'],
#  'owner': {'reputation': 2139,
#   'user_id': 3337089,
#   'user_type': 'registered',
#   'accept_rate': 86,
#   'profile_image': 'https://www.gravatar.com/avatar/b096725512960a65abe37b76c383de67?s=128&d=identicon&r=PG&f=1',
#   'display_name': 'Nagabhushan S N',
#   'link': 'https://stackoverflow.com/users/3337089/nagabhushan-s-n'},
#  'is_answered': True,
#  'view_count': 26,
#  'answer_count': 1,
#  'score': 5,
#  'last_activity_date': 1583723188,
#  'creation_date': 1583716704,
#  'question_id': 60593624,
#  'link': 'https://stackoverflow.com/questions/60593624/modify-trained-model-architecture-and-continue-training-keras',
#  'title': 'Modify trained model architecture and continue training Keras'}

# %%
import pandas as pd

quest = pd.DataFrame(questions['items'])

# %%
quest['title'].head(5)
# Out:
# 0    Modify trained model architecture and continue...
# 1    Find row average of tuples in data frame / 2d ...
# 2    How do I make independent lists within in a list?
# 3    groupby and withhold information of one column...
# 4    Partial keyword match not working when I am tr...
# Name: title, dtype: object

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
answers = SITE.fetch('answers', accepted_answer_id=[6784,6473])

# %%
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['asp.net-core', 'blazor-server-side'],
#    'owner': {'reputation': 107,
#     'user_id': 7440269,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/ada2b39a58b18cb618dbfa45f6316a2c?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'aleksander_si',
#     'link': 'https://stackoverflow.com/users/7440269/aleksander-si'},
#    'is_answered': True,
#    'view_count': 25,
#    'accepted_answer_id': 60607996,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786266,
#    'creation_date': 1578344327,
#    'last_edit_date': 1583786266,
#    'question_id': 59618898,
#    'link': 'https://stackoverflow.com/questions/59618898/how-to-correlate-blazor-activity-for-a-given-circuit-or-session',
#    'title': 'How to correlate Blazor activity for a given circuit or &quot;session&quot;'},
#   {'tags': ['python', 'pandas'],
#    'owner': {'reputation': 388,
#     'user_id': 10029062,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/1884febc1873a29864ba719bc5ca6376?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'arkadiy',
#     'link': 'https://stackoverflow.com/users/10029062/arkadiy'},
#    'is_answered': False,
#    'view_count': 6,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786265,
#    'creation_date': 1583786137,
#    'question_id': 60607982,
#    'link': 'https://stackoverflow.com/questions/60607982/copying-row-values-in-pandas-based-on-another-row-value',
#    'title': 'Copying row values in pandas based on another row value'},
#   {'tags': ['python', 'replace'],
#    'owner': {'reputation': 53,
#     'user_id': 11780729,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-_Y2fU2jqrA4/AAAAAAAAAAI/AAAAAAAACJc/3O7vJI0sobk/photo.jpg?sz=128',
#     'display_name': 'Jakob Nielsen',
#     'link': 'https://stackoverflow.com/users/11780729/jakob-nielsen'},
#    'is_answered': True,
#    'view_count': 41,
#    'accepted_answer_id': 60607737,
#    'answer_count': 3,
#    'score': 2,
#    'last_activity_date': 1583786265,
#    'creation_date': 1583784456,
#    'question_id': 60607645,
#    'link': 'https://stackoverflow.com/questions/60607645/variable-string-replacement-in-python',
#    'title': 'Variable string replacement in python'},
#   {'tags': ['c#', 'default', 'optional'],
#    'owner': {'reputation': 23,
#     'user_id': 13035268,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d55eb512e23431a198c38895575f3945?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'ciresuark',
#     'link': 'https://stackoverflow.com/users/13035268/ciresuark'},
#    'is_answered': True,
#    'view_count': 64,
#    'accepted_answer_id': 60607938,
#    'answer_count': 4,
#    'score': 1,
#    'last_activity_date': 1583786256,
#    'creation_date': 1583785160,
#    'question_id': 60607790,
#    'link': 'https://stackoverflow.com/questions/60607790/c-pass-an-integer-variable-with-an-optional-default-value',
#    'title': 'C# Pass an integer variable with an optional default value'},
#   {'tags': ['python', 'django'],
#    'owner': {'reputation': 9,
#     'user_id': 11766868,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-N3ExywoGnOY/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3reSwIvRMM3uvhwy0FdEDAt2ARNKaQ/photo.jpg?sz=128',
#     'display_name': 'AEP',
#     'link': 'https://stackoverflow.com/users/11766868/aep'},
#    'is_answered': False,
#    'view_count': 15,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1583786256,
#    'creation_date': 1583785681,
#    'question_id': 60607895,
#    'link': 'https://stackoverflow.com/questions/60607895/why-am-i-getting-the-pylint-error-value-self-body-is-unsubscriptable',
#    'title': 'Why am I getting the pylint error: Value &#39;self.body&#39; is unsubscriptable?'},
#   {'tags': ['javascript', 'html'],
#    'owner': {'reputation': 21,
#     'user_id': 13024221,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/b74449d8b982dbfef1427c6a830cb5f7?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'AylanJ123',
#     'link': 'https://stackoverflow.com/users/13024221/aylanj123'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786255,
#    'creation_date': 1583786255,
#    'question_id': 60608008,
#    'link': 'https://stackoverflow.com/questions/60608008/missing-after-arguments-list',
#    'title': 'Missing ) after arguments list'},
#   {'tags': ['sql', 'regex', 'oracle', 'teradata', 'ascii-art'],
#    'owner': {'reputation': 27897,
#     'user_id': 6336479,
#     'user_type': 'registered',
#     'accept_rate': 43,
#     'profile_image': 'https://lh4.googleusercontent.com/-7ttJnI3nmS4/AAAAAAAAAAI/AAAAAAAAJnE/jcRD1UDdrzE/photo.jpg?sz=128',
#     'display_name': 'David דודו Markovitz',
#     'link': 'https://stackoverflow.com/users/6336479/david-%d7%93%d7%95%d7%93%d7%95-markovitz'},
#    'is_answered': False,
#    'view_count': 127,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1583786254,
#    'creation_date': 1476608892,
#    'last_edit_date': 1554572807,
#    'question_id': 40068666,
#    'link': 'https://stackoverflow.com/questions/40068666/sql-regex-puzzle-challenge-how-to-convert-ascii-art-ranges-with-multiple-charact',
#    'title': 'SQL/REGEX puzzle/challenge How to convert ASCII art ranges with multiple characters to relational data?'},
#   {'tags': ['java', 'refactoring', 'static-methods'],
#    'owner': {'reputation': 13,
#     'user_id': 11037416,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/74005113dfafce80f00b93556d59b469?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'oumaymahd',
#     'link': 'https://stackoverflow.com/users/11037416/oumaymahd'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786251,
#    'creation_date': 1583786251,
#    'question_id': 60608006,
#    'link': 'https://stackoverflow.com/questions/60608006/question-about-static-method-and-refactorings-move-method-push-down-method-and',
#    'title': 'Question about static Method and refactorings (Move Method, Push Down Method and Pull Up Method)'},
#   {'tags': ['javascript', 'loops', 'for-loop', 'knex.js'],
#    'owner': {'reputation': 3,
#     'user_id': 12093405,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/2475553822676226/picture?type=large',
#     'display_name': 'Marouane Belbouhali',
#     'link': 'https://stackoverflow.com/users/12093405/marouane-belbouhali'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786248,
#    'creation_date': 1583786248,
#    'question_id': 60608005,
#    'link': 'https://stackoverflow.com/questions/60608005/loop-for-on-knexjs',
#    'title': 'Loop for on KnexJS'},
#   {'tags': ['wix', 'windows-installer', 'upgrade'],
#    'owner': {'reputation': 217,
#     'user_id': 1109342,
#     'user_type': 'registered',
#     'accept_rate': 57,
#     'profile_image': 'https://i.stack.imgur.com/uV96C.png?s=128&g=1',
#     'display_name': 'Andrei Petrut',
#     'link': 'https://stackoverflow.com/users/1109342/andrei-petrut'},
#    'is_answered': False,
#    'view_count': 56,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786246,
#    'creation_date': 1583252074,
#    'last_edit_date': 1583786246,
#    'question_id': 60511416,
#    'link': 'https://stackoverflow.com/questions/60511416/upgrade-to-a-newer-version-using-wix-installer-doesnt-copy-the-new-files',
#    'title': 'Upgrade to a newer version using WIX Installer doesn&#39;t copy the new files'},
#   {'tags': ['java', 'javafx', 'nullpointerexception'],
#    'owner': {'reputation': 59,
#     'user_id': 12094608,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AAuE7mDAfgvhCrhF2JkFCYHYG6gEHr70u3KIZS5PiFpPfg=k-s128',
#     'display_name': 'KamielDev',
#     'link': 'https://stackoverflow.com/users/12094608/kamieldev'},
#    'is_answered': False,
#    'view_count': 53,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1583786237,
#    'creation_date': 1583696807,
#    'last_edit_date': 1583786237,
#    'question_id': 60591428,
#    'link': 'https://stackoverflow.com/questions/60591428/nullpointerexception-occurs-after-updating-the-items-of-a-combobox',
#    'title': 'NullPointerException occurs after updating the items of a ComboBox'},
#   {'tags': ['javascript', 'css'],
#    'owner': {'reputation': 31,
#     'user_id': 12287828,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/00c522bba7413293836782a3dd7dfa08?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'reti',
#     'link': 'https://stackoverflow.com/users/12287828/reti'},
#    'is_answered': False,
#    'view_count': 23,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786232,
#    'creation_date': 1583783331,
#    'last_edit_date': 1583784491,
#    'question_id': 60607411,
#    'link': 'https://stackoverflow.com/questions/60607411/sidebar-navigation-with-columns',
#    'title': 'sidebar navigation with columns'},
#   {'tags': ['reactjs', 'redux', 'redux-thunk'],
#    'owner': {'reputation': 1189,
#     'user_id': 908126,
#     'user_type': 'registered',
#     'accept_rate': 70,
#     'profile_image': 'https://www.gravatar.com/avatar/2bcf7ea34f99211d65267c64e6dbf360?s=128&d=identicon&r=PG',
#     'display_name': 'angus',
#     'link': 'https://stackoverflow.com/users/908126/angus'},
#    'is_answered': False,
#    'view_count': 15,
#    'answer_count': 1,
#    'score': -1,
#    'last_activity_date': 1583786232,
#    'creation_date': 1583784689,
#    'question_id': 60607690,
#    'link': 'https://stackoverflow.com/questions/60607690/send-rest-call-in-a-loop',
#    'title': 'Send Rest call in a loop'},
#   {'tags': ['php', 'composer-php', 'macos-catalina'],
#    'owner': {'reputation': 51,
#     'user_id': 8640984,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-PpyKZDHnrkw/AAAAAAAAAAI/AAAAAAAAAC8/pKikkKR2JPU/photo.jpg?sz=128',
#     'display_name': 'John Walker',
#     'link': 'https://stackoverflow.com/users/8640984/john-walker'},
#    'is_answered': False,
#    'view_count': 22,
#    'answer_count': 0,
#    'score': -1,
#    'last_activity_date': 1583786225,
#    'creation_date': 1583772106,
#    'last_edit_date': 1583786225,
#    'question_id': 60604926,
#    'link': 'https://stackoverflow.com/questions/60604926/short-term-workaround-of-macos-catalinas-missing-zip-extension-when-running-com',
#    'title': 'Short term workaround of MacOs Catalina&#39;s missing zip extension when running composer install / update?'},
#   {'tags': ['powershell'],
#    'owner': {'reputation': 15,
#     'user_id': 12980185,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/6fe86394d19dae30ebc139c2890ead6d?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'vabax',
#     'link': 'https://stackoverflow.com/users/12980185/vabax'},
#    'is_answered': False,
#    'view_count': 9,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786224,
#    'creation_date': 1583785382,
#    'question_id': 60607844,
#    'link': 'https://stackoverflow.com/questions/60607844/error-parameter-set-cannot-be-resolved-using-the-specified-named-parameters',
#    'title': 'Error: Parameter set cannot be resolved using the specified named parameters'},
#   {'tags': ['angular', 'components', 'share'],
#    'owner': {'reputation': 475,
#     'user_id': 8086276,
#     'user_type': 'registered',
#     'accept_rate': 68,
#     'profile_image': 'https://www.gravatar.com/avatar/d390934ccdb41c44fa69018ae8c8ab77?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Mellville',
#     'link': 'https://stackoverflow.com/users/8086276/mellville'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786218,
#    'creation_date': 1583786218,
#    'question_id': 60608001,
#    'link': 'https://stackoverflow.com/questions/60608001/passing-boolean-through-local-service-doesnt-work',
#    'title': 'passing boolean through local service doesn&#39;t work'},
#   {'tags': ['python', 'pandas', 'loops', 'dataframe', 'cryptocurrency'],
#    'owner': {'reputation': 11,
#     'user_id': 3919889,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/57c81ea7f442c844fe1cc579cc090254?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'ciucciodifuoco',
#     'link': 'https://stackoverflow.com/users/3919889/ciucciodifuoco'},
#    'is_answered': False,
#    'view_count': 26,
#    'answer_count': 1,
#    'score': 1,
#    'last_activity_date': 1583786218,
#    'creation_date': 1583784874,
#    'question_id': 60607729,
#    'link': 'https://stackoverflow.com/questions/60607729/is-there-a-better-way-of-doing-this-ideally-with-a-single-loop',
#    'title': 'Is there a better way of doing this (ideally with a single loop)'},
#   {'tags': ['c#', 'asp.net-core', 'path', 'filepath', 'razor-pages'],
#    'owner': {'reputation': 1,
#     'user_id': 12280081,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/OSxqT.png?s=128&g=1',
#     'display_name': 'LexLocked',
#     'link': 'https://stackoverflow.com/users/12280081/lexlocked'},
#    'is_answered': False,
#    'view_count': 14,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786215,
#    'creation_date': 1583779860,
#    'question_id': 60606663,
#    'link': 'https://stackoverflow.com/questions/60606663/asp-net-core-custom-absolute-root-path',
#    'title': 'ASP.Net Core Custom Absolute Root Path'},
#   {'tags': ['scikit-learn', 'hidden-markov-models', 'hmmlearn'],
#    'owner': {'reputation': 1248,
#     'user_id': 3449744,
#     'user_type': 'registered',
#     'accept_rate': 86,
#     'profile_image': 'https://www.gravatar.com/avatar/b409bb791bfe5c739a5cf36c9611ee94?s=128&d=identicon&r=PG',
#     'display_name': 'Vilda',
#     'link': 'https://stackoverflow.com/users/3449744/vilda'},
#    'is_answered': False,
#    'view_count': 12,
#    'answer_count': 0,
#    'score': 1,
#    'last_activity_date': 1583786214,
#    'creation_date': 1583778438,
#    'last_edit_date': 1583786214,
#    'question_id': 60606381,
#    'link': 'https://stackoverflow.com/questions/60606381/multiple-variables-with-hmmlearn-multinomialhmm',
#    'title': 'Multiple variables with hmmlearn MultinomialHMM'},
#   {'tags': ['python', 'cython'],
#    'owner': {'reputation': 11,
#     'user_id': 11128923,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/f9473b93842fef5b3687c4d8532afb38?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Carina Chen',
#     'link': 'https://stackoverflow.com/users/11128923/carina-chen'},
#    'is_answered': False,
#    'view_count': 31,
#    'answer_count': 1,
#    'score': 1,
#    'last_activity_date': 1583786210,
#    'creation_date': 1583703130,
#    'last_edit_date': 1583785219,
#    'question_id': 60592268,
#    'link': 'https://stackoverflow.com/questions/60592268/command-gcc-failed-with-exit-status-1-when-running-cython-in-jupyter-noteb',
#    'title': '&quot;command &#39;gcc&#39; failed with exit status 1&quot; when running %%cython in jupyter notebook'},
#   {'tags': ['javascript', 'json'],
#    'owner': {'reputation': 41,
#     'user_id': 11819506,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/7af4aaebf92baa82d794a22afb79747f?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Heithwald',
#     'link': 'https://stackoverflow.com/users/11819506/heithwald'},
#    'is_answered': True,
#    'view_count': 32,
#    'answer_count': 2,
#    'score': 4,
#    'last_activity_date': 1583786208,
#    'creation_date': 1583785428,
#    'question_id': 60607853,
#    'link': 'https://stackoverflow.com/questions/60607853/how-to-log-form-inputs-in-a-json-object-with-vanilla-js',
#    'title': 'How to log form inputs in a JSON object with vanilla JS?'},
#   {'tags': ['c#', 'unity3d', 'input', 'swipe'],
#    'owner': {'reputation': 47,
#     'user_id': 5504527,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/3dbb62521cb8de1871ddc0f17e4b42d3?s=128&d=identicon&r=PG',
#     'display_name': 'xXElsterXx',
#     'link': 'https://stackoverflow.com/users/5504527/xxelsterxx'},
#    'is_answered': False,
#    'view_count': 5,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786204,
#    'creation_date': 1583786204,
#    'question_id': 60607995,
#    'link': 'https://stackoverflow.com/questions/60607995/unity-c-swipe-cause-getmousebuttondown0',
#    'title': 'Unity C#: Swipe cause GetMouseButtonDown(0)'},
#   {'tags': ['stack', 'overflow', 'points'],
#    'owner': {'reputation': 34,
#     'user_id': 7837073,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-nBmyL5cYxBo/AAAAAAAAAAI/AAAAAAAAAEU/0ZPlriThYR0/photo.jpg?sz=128',
#     'display_name': 'Frank Thomas',
#     'link': 'https://stackoverflow.com/users/7837073/frank-thomas'},
#    'is_answered': False,
#    'view_count': 7,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786202,
#    'creation_date': 1583785208,
#    'question_id': 60607804,
#    'link': 'https://stackoverflow.com/questions/60607804/how-do-i-get-reputation-points',
#    'title': 'How Do I Get Reputation Points'},
#   {'tags': ['java'],
#    'owner': {'reputation': 1,
#     'user_id': 13035194,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-XxCEViTkdkg/AAAAAAAAAAI/AAAAAAAAAAA/AKF05nA7M5c5r_g7P2HhwtJzW62KmN8Xfg/photo.jpg?sz=128',
#     'display_name': 'TTTT',
#     'link': 'https://stackoverflow.com/users/13035194/tttt'},
#    'is_answered': False,
#    'view_count': 25,
#    'answer_count': 1,
#    'score': -3,
#    'last_activity_date': 1583786197,
#    'creation_date': 1583784382,
#    'question_id': 60607631,
#    'link': 'https://stackoverflow.com/questions/60607631/invalid-input-validation-java',
#    'title': 'Invalid Input Validation Java'},
#   {'tags': ['shopify', 'shopify-api'],
#    'owner': {'reputation': 5412,
#     'user_id': 485352,
#     'user_type': 'registered',
#     'accept_rate': 90,
#     'profile_image': 'https://www.gravatar.com/avatar/32550cd9f1492acdedd71fe82ee95267?s=128&d=identicon&r=PG',
#     'display_name': 'cgossain',
#     'link': 'https://stackoverflow.com/users/485352/cgossain'},
#    'is_answered': False,
#    'view_count': 8,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786193,
#    'creation_date': 1583780714,
#    'question_id': 60606840,
#    'link': 'https://stackoverflow.com/questions/60606840/how-to-cancel-and-restock-order-using-shopify-api',
#    'title': 'How to cancel and restock order using Shopify API?'},
#   {'tags': ['templates',
#     'kubernetes',
#     'charts',
#     'overriding',
#     'kubernetes-helm'],
#    'owner': {'reputation': 12713,
#     'user_id': 423868,
#     'user_type': 'registered',
#     'accept_rate': 65,
#     'profile_image': 'https://i.stack.imgur.com/l4jLj.jpg?s=128&g=1',
#     'display_name': 'Georgy Gobozov',
#     'link': 'https://stackoverflow.com/users/423868/georgy-gobozov'},
#    'is_answered': False,
#    'view_count': 32,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786192,
#    'creation_date': 1583535193,
#    'question_id': 60572620,
#    'link': 'https://stackoverflow.com/questions/60572620/helm-override-common-template-values',
#    'title': 'Helm Override common template values'},
#   {'tags': ['python', 'spell-checking', 'autocorrect'],
#    'owner': {'reputation': 15,
#     'user_id': 3191371,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/3b05d5ec7450a96eeb2970ba238a1615?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'user3191371',
#     'link': 'https://stackoverflow.com/users/3191371/user3191371'},
#    'is_answered': False,
#    'view_count': 22,
#    'answer_count': 2,
#    'score': 1,
#    'last_activity_date': 1583786182,
#    'creation_date': 1583785231,
#    'last_edit_date': 1583785345,
#    'question_id': 60607809,
#    'link': 'https://stackoverflow.com/questions/60607809/pyspellchecker-do-not-split-url',
#    'title': 'pyspellchecker: do not split URL'},
#   {'tags': ['javascript', 'reactjs', 'chart.js'],
#    'owner': {'reputation': 309,
#     'user_id': 4863162,
#     'user_type': 'registered',
#     'accept_rate': 60,
#     'profile_image': 'https://i.stack.imgur.com/8BPdE.jpg?s=128&g=1',
#     'display_name': 'jarwin',
#     'link': 'https://stackoverflow.com/users/4863162/jarwin'},
#    'is_answered': False,
#    'view_count': 24,
#    'answer_count': 1,
#    'score': -1,
#    'last_activity_date': 1583786181,
#    'creation_date': 1583784077,
#    'last_edit_date': 1583785709,
#    'question_id': 60607559,
#    'link': 'https://stackoverflow.com/questions/60607559/chart-js-update-is-not-a-function',
#    'title': 'chart.js update is not a function'},
#   {'tags': ['javascript', 'reactjs', 'redux', 'react-redux'],
#    'owner': {'reputation': 1,
#     'user_id': 11936170,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-N_gsU0zh9D0/AAAAAAAAAAI/AAAAAAAAAAA/AAN31DUfCloJ5UI1fQbSl7FpixKkq6OyBA/mo/photo.jpg?sz=128',
#     'display_name': 'Nojus Kudaba',
#     'link': 'https://stackoverflow.com/users/11936170/nojus-kudaba'},
#    'is_answered': False,
#    'view_count': 5,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786173,
#    'creation_date': 1583786173,
#    'question_id': 60607989,
#    'link': 'https://stackoverflow.com/questions/60607989/react-redux-prop-is-undefined',
#    'title': 'React Redux prop is undefined'},
#   {'tags': ['javascript', 'html', 'twitter-bootstrap'],
#    'owner': {'reputation': 5351,
#     'user_id': 846281,
#     'user_type': 'registered',
#     'accept_rate': 88,
#     'profile_image': 'https://www.gravatar.com/avatar/01438c3df63caf4c986268852935fcbd?s=128&d=identicon&r=PG',
#     'display_name': 'Andrew Simpson',
#     'link': 'https://stackoverflow.com/users/846281/andrew-simpson'},
#    'is_answered': True,
#    'view_count': 32978,
#    'accepted_answer_id': 26178517,
#    'answer_count': 8,
#    'score': 15,
#    'last_activity_date': 1583786170,
#    'creation_date': 1412337064,
#    'last_edit_date': 1413328248,
#    'question_id': 26178441,
#    'link': 'https://stackoverflow.com/questions/26178441/how-to-toggle-a-highlighted-selected-item-in-a-group-list',
#    'title': 'How to toggle a highlighted selected item in a group list'},
#   {'tags': ['git', 'github', 'git-describe'],
#    'owner': {'reputation': 17387,
#     'user_id': 131929,
#     'user_type': 'registered',
#     'accept_rate': 83,
#     'profile_image': 'https://www.gravatar.com/avatar/06780f50c30ffab584630481476ba6f4?s=128&d=identicon&r=PG',
#     'display_name': 'Marcel St&#246;r',
#     'link': 'https://stackoverflow.com/users/131929/marcel-st%c3%b6r'},
#    'is_answered': True,
#    'view_count': 405,
#    'accepted_answer_id': 57697016,
#    'answer_count': 2,
#    'score': 2,
#    'last_activity_date': 1583786166,
#    'creation_date': 1566969082,
#    'question_id': 57685432,
#    'link': 'https://stackoverflow.com/questions/57685432/make-git-show-the-correct-tag-on-branches-with-git-describe',
#    'title': 'Make Git show the correct tag on branches with git describe'},
#   {'tags': ['c#', '.net', 'azure', 'azure-functions', 'azureservicebus'],
#    'owner': {'reputation': 87,
#     'user_id': 7114196,
#     'user_type': 'registered',
#     'accept_rate': 36,
#     'profile_image': 'https://www.gravatar.com/avatar/104b2345ae60b8c854315deac194a0d5?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Kenny_I',
#     'link': 'https://stackoverflow.com/users/7114196/kenny-i'},
#    'is_answered': False,
#    'view_count': 7,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786163,
#    'creation_date': 1583785596,
#    'last_edit_date': 1583786163,
#    'question_id': 60607880,
#    'link': 'https://stackoverflow.com/questions/60607880/how-to-send-data-to-service-bus-topic-with-azure-functions',
#    'title': 'How to send data to Service Bus Topic with Azure Functions?'},
#   {'tags': ['java'],
#    'owner': {'reputation': 33,
#     'user_id': 11713444,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-L1exr8OOmPY/AAAAAAAAAAI/AAAAAAAABGs/JsPgkmdYPvE/photo.jpg?sz=128',
#     'display_name': 'Minvy',
#     'link': 'https://stackoverflow.com/users/11713444/minvy'},
#    'is_answered': False,
#    'view_count': 6,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786158,
#    'creation_date': 1583786158,
#    'question_id': 60607987,
#    'link': 'https://stackoverflow.com/questions/60607987/java-console-application-asterisk-password',
#    'title': 'Java console application asterisk password'},
#   {'tags': ['javascript', 'php', 'jquery', 'html', 'css'],
#    'owner': {'reputation': 1,
#     'user_id': 2952535,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/100001171326489/picture?type=large',
#     'display_name': 'Faisal Khan',
#     'link': 'https://stackoverflow.com/users/2952535/faisal-khan'},
#    'is_answered': False,
#    'view_count': 8,
#    'answer_count': 0,
#    'score': -1,
#    'last_activity_date': 1583786154,
#    'creation_date': 1583786076,
#    'last_edit_date': 1583786154,
#    'question_id': 60607973,
#    'link': 'https://stackoverflow.com/questions/60607973/add-required-checkbox-to-a-custom-button',
#    'title': 'Add required Checkbox to a custom button'},
#   {'tags': ['javascript', 'google-chrome'],
#    'owner': {'reputation': 29,
#     'user_id': 5684299,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a5000b6424b305cb9b3f35dd346b0346?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Moatassem',
#     'link': 'https://stackoverflow.com/users/5684299/moatassem'},
#    'is_answered': False,
#    'view_count': 16,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786153,
#    'creation_date': 1583702584,
#    'question_id': 60592196,
#    'link': 'https://stackoverflow.com/questions/60592196/chrome-keeps-sending-get-for-sses',
#    'title': 'Chrome Keeps Sending GET for SSEs'},
#   {'tags': ['project-reactor'],
#    'owner': {'reputation': 1,
#     'user_id': 12860662,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-omPpyasbIlE/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rcero2WmH8izpreqTB3K29MEWPN8A/photo.jpg?sz=128',
#     'display_name': 'Deepak Bhimaraju',
#     'link': 'https://stackoverflow.com/users/12860662/deepak-bhimaraju'},
#    'is_answered': False,
#    'view_count': 6,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786152,
#    'creation_date': 1583784848,
#    'question_id': 60607724,
#    'link': 'https://stackoverflow.com/questions/60607724/when-does-reactor-execute-a-subscription-chain',
#    'title': 'When does reactor execute a subscription chain?'},
#   {'tags': ['windows', 'docker', 'hyper-v'],
#    'owner': {'reputation': 119,
#     'user_id': 7133383,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/673a9ec129be2060c0fde6616f4eb0b5?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'RunThor',
#     'link': 'https://stackoverflow.com/users/7133383/runthor'},
#    'is_answered': False,
#    'view_count': 30,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786150,
#    'creation_date': 1583356740,
#    'last_edit_date': 1583530149,
#    'question_id': 60534877,
#    'link': 'https://stackoverflow.com/questions/60534877/docker-on-windows-10-networking-issue',
#    'title': 'Docker on Windows 10 networking issue'},
#   {'tags': ['spring-boot', 'spring-mvc', 'thymeleaf'],
#    'owner': {'reputation': 763,
#     'user_id': 4398914,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/d0eca75389d115fc16c0ba3852a42734?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'mobileDev',
#     'link': 'https://stackoverflow.com/users/4398914/mobiledev'},
#    'is_answered': False,
#    'view_count': 13,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786146,
#    'creation_date': 1583781558,
#    'last_edit_date': 1583786146,
#    'question_id': 60607043,
#    'link': 'https://stackoverflow.com/questions/60607043/spring-mvc-doesnt-show-images-after-adding-swagger',
#    'title': 'Spring MVC doesn&#39;t show images after adding swagger'},
#   {'tags': ['kubernetes',
#     'minikube',
#     'kubernetes-ingress',
#     'kubernetes-dashboard'],
#    'owner': {'reputation': 767,
#     'user_id': 4575603,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-5GpzzPrXl58/AAAAAAAAAAI/AAAAAAAAAHM/1yDgcMHMCSM/photo.jpg?sz=128',
#     'display_name': 'Nitesh',
#     'link': 'https://stackoverflow.com/users/4575603/nitesh'},
#    'is_answered': True,
#    'view_count': 1001,
#    'accepted_answer_id': 54666806,
#    'answer_count': 3,
#    'score': 3,
#    'last_activity_date': 1583786140,
#    'creation_date': 1550040790,
#    'question_id': 54664233,
#    'link': 'https://stackoverflow.com/questions/54664233/how-to-delete-kubernetes-dashboard-from-kube-system',
#    'title': 'How to delete kubernetes dashboard from kube-system?'},
#   {'tags': ['react-native',
#     'clojurescript',
#     'react-native-camera',
#     're-natal'],
#    'owner': {'reputation': 658,
#     'user_id': 5440125,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/5368403fa6c1aa62270f86373269777f?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'zengod',
#     'link': 'https://stackoverflow.com/users/5440125/zengod'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786138,
#    'creation_date': 1583786138,
#    'question_id': 60607983,
#    'link': 'https://stackoverflow.com/questions/60607983/unable-to-import-react-native-camera-in-re-natal',
#    'title': 'Unable to import react-native-camera in re-natal'},
#   {'tags': ['reactjs'],
#    'owner': {'reputation': 165,
#     'user_id': 3913519,
#     'user_type': 'registered',
#     'accept_rate': 33,
#     'profile_image': 'https://www.gravatar.com/avatar/41522b2486454b12ae89c28df51ce595?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Jon Doe',
#     'link': 'https://stackoverflow.com/users/3913519/jon-doe'},
#    'is_answered': False,
#    'view_count': 4,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786130,
#    'creation_date': 1583786130,
#    'question_id': 60607981,
#    'link': 'https://stackoverflow.com/questions/60607981/react-text-field-triggers-syntheticevent',
#    'title': 'React Text Field triggers SyntheticEvent'},
#   {'tags': ['arrays', 'reactjs', 'components', 'gatsby', 'react-props'],
#    'owner': {'reputation': 75,
#     'user_id': 2972018,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/cd47bc215815c0e9b24a6161882f40e9?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'visionInc',
#     'link': 'https://stackoverflow.com/users/2972018/visioninc'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786126,
#    'creation_date': 1583786126,
#    'question_id': 60607980,
#    'link': 'https://stackoverflow.com/questions/60607980/react-accessing-props-arrays-length-in-a-component-leads-to-typeerror-propert',
#    'title': 'React: Accessing props array&#39;s length in a component leads to TypeError (property undefined)'},
#   {'tags': ['php', 'curl'],
#    'owner': {'reputation': 4481,
#     'user_id': 3067928,
#     'user_type': 'registered',
#     'accept_rate': 43,
#     'profile_image': 'https://www.gravatar.com/avatar/16fa1506d4412e204a64ccee50998fd8?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Ronak Patel',
#     'link': 'https://stackoverflow.com/users/3067928/ronak-patel'},
#    'is_answered': False,
#    'view_count': 13,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786124,
#    'creation_date': 1583785699,
#    'last_edit_date': 1583786124,
#    'question_id': 60607900,
#    'link': 'https://stackoverflow.com/questions/60607900/get-body-content-from-xml-in-php-curl-request',
#    'title': 'Get body content from xml in php curl request'},
#   {'tags': ['angular', 'dependency-injection', 'angular-http-interceptors'],
#    'owner': {'reputation': 1034,
#     'user_id': 1106057,
#     'user_type': 'registered',
#     'accept_rate': 57,
#     'profile_image': 'https://www.gravatar.com/avatar/449ee6c1d41632f727db131d5828cc42?s=128&d=identicon&r=PG',
#     'display_name': 'jeff.eynon',
#     'link': 'https://stackoverflow.com/users/1106057/jeff-eynon'},
#    'is_answered': False,
#    'view_count': 11,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786118,
#    'creation_date': 1583784764,
#    'question_id': 60607703,
#    'link': 'https://stackoverflow.com/questions/60607703/angular-7-injected-service-is-always-null',
#    'title': 'Angular 7 - injected service is always null'},
#   {'tags': ['codenameone'],
#    'owner': {'reputation': 71,
#     'user_id': 9626186,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/-w9F7Y4cHs0g/AAAAAAAAAAI/AAAAAAAAAAw/YkV5C6lqGQU/photo.jpg?sz=128',
#     'display_name': 'Tumwesigye Benjamin',
#     'link': 'https://stackoverflow.com/users/9626186/tumwesigye-benjamin'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786117,
#    'creation_date': 1583786117,
#    'question_id': 60607978,
#    'link': 'https://stackoverflow.com/questions/60607978/codename-one-i-want-to-create-a-list-of-10-items-with-icons-and-a-checkbox-if-an',
#    'title': 'codename one i want to create a list of 10 items with icons and a checkbox if an item is selected'},
#   {'tags': ['c++', 'opencv', 'memory', 'corruption'],
#    'owner': {'reputation': 323,
#     'user_id': 2863527,
#     'user_type': 'registered',
#     'accept_rate': 38,
#     'profile_image': 'https://www.gravatar.com/avatar/fe9dc5d0e50b50eab8b54a1e0334852b?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'trexgris',
#     'link': 'https://stackoverflow.com/users/2863527/trexgris'},
#    'is_answered': True,
#    'view_count': 1242,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1583786115,
#    'creation_date': 1393250485,
#    'last_edit_date': 1583786115,
#    'question_id': 21989970,
#    'link': 'https://stackoverflow.com/questions/21989970/opencv-memory-corruption',
#    'title': 'OpenCV: memory corruption'},
#   {'tags': ['scala', 'circe'],
#    'owner': {'reputation': 45,
#     'user_id': 12515377,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-fQ1dnnme4K8/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rcyN7sp3VXiioYggYewREt5w0d04w/photo.jpg?sz=128',
#     'display_name': 'Arjun Karnwal',
#     'link': 'https://stackoverflow.com/users/12515377/arjun-karnwal'},
#    'is_answered': False,
#    'view_count': 9,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786109,
#    'creation_date': 1583784411,
#    'last_edit_date': 1583786109,
#    'question_id': 60607635,
#    'link': 'https://stackoverflow.com/questions/60607635/circe-failed-to-decode-json-containing-list',
#    'title': 'Circe failed to decode JSON containing list'},
#   {'tags': ['sqoop'],
#    'owner': {'reputation': 1,
#     'user_id': 13035263,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/75e33cdb27d24e762fc566ce5fadffad?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Raky_tech',
#     'link': 'https://stackoverflow.com/users/13035263/raky-tech'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786108,
#    'creation_date': 1583786108,
#    'question_id': 60607977,
#    'link': 'https://stackoverflow.com/questions/60607977/sqoop-options-to-load-a-lob-column-from-rdbms-to-hive',
#    'title': 'Sqoop options to load a LOB column from rdbms to Hive'},
#   {'tags': ['java', 'date', 'time', 'java.time'],
#    'owner': {'reputation': 33,
#     'user_id': 9983252,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-tppbvoaJLeE/AAAAAAAAAAI/AAAAAAAAATg/q_An_d6LPVM/photo.jpg?sz=128',
#     'display_name': 'Yash Damani',
#     'link': 'https://stackoverflow.com/users/9983252/yash-damani'},
#    'is_answered': True,
#    'view_count': 28,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1583786107,
#    'creation_date': 1583785153,
#    'question_id': 60607789,
#    'link': 'https://stackoverflow.com/questions/60607789/how-to-find-the-next-days-date-with-midnight-as-its-time-given-a-instant-date',
#    'title': 'How to find the next day&#39;s date with midnight as it&#39;s time given a Instant date?'},
#   {'tags': ['python', 'list', 'for-loop', 'f-string'],
#    'owner': {'reputation': 4603,
#     'user_id': 1585017,
#     'user_type': 'registered',
#     'accept_rate': 59,
#     'profile_image': 'https://www.gravatar.com/avatar/2f061e81d1b40974aae8330e25fd2296?s=128&d=identicon&r=PG',
#     'display_name': 'multigoodverse',
#     'link': 'https://stackoverflow.com/users/1585017/multigoodverse'},
#    'is_answered': True,
#    'view_count': 30,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786103,
#    'creation_date': 1583768572,
#    'last_edit_date': 1583781324,
#    'question_id': 60603965,
#    'link': 'https://stackoverflow.com/questions/60603965/constructing-an-f-string-by-for-looping-through-a-list',
#    'title': 'Constructing an f-string by for-looping through a list'},
#   {'tags': ['c++', 'arrays', 'algorithm', 'pointers'],
#    'owner': {'reputation': 1,
#     'user_id': 12880805,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d42153dc17af0e0116e1bcd8433f5cfb?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'mai assem',
#     'link': 'https://stackoverflow.com/users/12880805/mai-assem'},
#    'is_answered': False,
#    'view_count': 23,
#    'closed_date': 1583785778,
#    'answer_count': 0,
#    'score': -2,
#    'last_activity_date': 1583786100,
#    'creation_date': 1583785636,
#    'last_edit_date': 1583786100,
#    'question_id': 60607889,
#    'link': 'https://stackoverflow.com/questions/60607889/what-is-the-meaning-of-arrs-true',
#    'closed_reason': 'Needs details or clarity',
#    'title': 'what is the meaning of `arr[s] = true`?'},
#   {'tags': ['android',
#     'eclipse',
#     'compiler-errors',
#     'android-resources',
#     'android-sdk-tools'],
#    'owner': {'reputation': 2614,
#     'user_id': 61996,
#     'user_type': 'registered',
#     'accept_rate': 59,
#     'profile_image': 'https://i.stack.imgur.com/mXn8L.jpg?s=128&g=1',
#     'display_name': 'Maurizio Pozzobon',
#     'link': 'https://stackoverflow.com/users/61996/maurizio-pozzobon'},
#    'is_answered': True,
#    'view_count': 895455,
#    'protected_date': 1290169048,
#    'accepted_answer_id': 886494,
#    'answer_count': 107,
#    'community_owned_date': 1316690563,
#    'score': 1060,
#    'last_activity_date': 1583786100,
#    'creation_date': 1242766940,
#    'last_edit_date': 1466066463,
#    'question_id': 885009,
#    'link': 'https://stackoverflow.com/questions/885009/r-cannot-be-resolved-android-error',
#    'title': 'R cannot be resolved - Android error'},
#   {'tags': ['root', 'sudo', 'permission-denied', 'unlink', 'npm-update'],
#    'owner': {'reputation': 1313,
#     'user_id': 12240619,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AAuE7mDAVJSh5xpkp0sTe6yMxfyxx-FDwRs_iVO8f5-BaQ=k-s128',
#     'display_name': 'Jennifer Espinoza',
#     'link': 'https://stackoverflow.com/users/12240619/jennifer-espinoza'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786097,
#    'creation_date': 1583786097,
#    'question_id': 60607976,
#    'link': 'https://stackoverflow.com/questions/60607976/error-eacces-permission-denied-unlink-usr-local-bin-npm',
#    'title': 'Error: EACCES: permission denied, unlink &#39;/usr/local/bin/npm'},
#   {'tags': ['c#', 'omnisharp', 'editorconfig'],
#    'owner': {'reputation': 2775,
#     'user_id': 182894,
#     'user_type': 'registered',
#     'accept_rate': 63,
#     'profile_image': 'https://www.gravatar.com/avatar/df52847e53e2233d2927c5fe09d2f62b?s=128&d=identicon&r=PG',
#     'display_name': 'roydukkey',
#     'link': 'https://stackoverflow.com/users/182894/roydukkey'},
#    'is_answered': False,
#    'view_count': 5,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786091,
#    'creation_date': 1583786091,
#    'question_id': 60607975,
#    'link': 'https://stackoverflow.com/questions/60607975/omnisharp-for-vs-code-still-doesnt-seem-to-respect-editorconfig-settings',
#    'title': 'Omnisharp for VS Code still doesn&#39;t seem to respect .editorconfig settings'},
#   {'tags': ['rust', 'unsafe', 'clamp'],
#    'owner': {'reputation': 79,
#     'user_id': 7171515,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-ZGdGkNObJjg/AAAAAAAAAAI/AAAAAAAAABo/EgEq4bGsVG0/photo.jpg?sz=128',
#     'display_name': 'Alexander Vtyurin',
#     'link': 'https://stackoverflow.com/users/7171515/alexander-vtyurin'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786079,
#    'creation_date': 1583786079,
#    'question_id': 60607974,
#    'link': 'https://stackoverflow.com/questions/60607974/how-to-implement-ord-trait-in-rust',
#    'title': 'How to implement Ord trait in rust?'},
#   {'tags': ['android',
#     'onclicklistener',
#     'navigationview',
#     'programmatically-created'],
#    'owner': {'reputation': 9,
#     'user_id': 11417864,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-r1iygGFhfMg/AAAAAAAAAAI/AAAAAAAAABQ/l-cz0AvuTLc/photo.jpg?sz=128',
#     'display_name': 'Scepticul',
#     'link': 'https://stackoverflow.com/users/11417864/scepticul'},
#    'is_answered': False,
#    'view_count': 14,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786075,
#    'creation_date': 1583777914,
#    'last_edit_date': 1583786075,
#    'question_id': 60606256,
#    'link': 'https://stackoverflow.com/questions/60606256/how-to-set-onclicklistener-for-the-newly-added-item-to-navigationview',
#    'title': 'How to set onClickListener for the newly added item to navigationview?'},
#   {'tags': ['java', 'mysql', 'spring-boot', 'maven', 'jpa'],
#    'owner': {'reputation': 3310,
#     'user_id': 146234,
#     'user_type': 'registered',
#     'accept_rate': 40,
#     'profile_image': 'https://www.gravatar.com/avatar/903ccadd292c66cf8d231d664f753f50?s=128&d=identicon&r=PG',
#     'display_name': 'PacificNW_Lover',
#     'link': 'https://stackoverflow.com/users/146234/pacificnw-lover'},
#    'is_answered': False,
#    'view_count': 19,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786072,
#    'creation_date': 1583784021,
#    'last_edit_date': 1583786072,
#    'question_id': 60607545,
#    'link': 'https://stackoverflow.com/questions/60607545/spring-boot-jpa-or-sql-query-to-find-most-common-item-in-joined-tables',
#    'title': 'Spring Boot - JPA or SQL Query to find Most Common Item in Joined Tables?'},
#   {'tags': ['cron', 'amazon-lightsail'],
#    'owner': {'reputation': 31,
#     'user_id': 1983244,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/873fec500765d69e2010832ae27bff18?s=128&d=identicon&r=PG',
#     'display_name': 'user1983244',
#     'link': 'https://stackoverflow.com/users/1983244/user1983244'},
#    'is_answered': False,
#    'view_count': 5,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786070,
#    'creation_date': 1583784416,
#    'question_id': 60607637,
#    'link': 'https://stackoverflow.com/questions/60607637/crontab-e-not-working-but-crontab-l-works',
#    'title': 'Crontab -e not working. but crontab -l works'},
#   {'tags': ['typescript'],
#    'owner': {'reputation': 5129,
#     'user_id': 2768271,
#     'user_type': 'registered',
#     'accept_rate': 97,
#     'profile_image': 'https://www.gravatar.com/avatar/6634769f91418767c464fbe38b3aef05?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'swelet',
#     'link': 'https://stackoverflow.com/users/2768271/swelet'},
#    'is_answered': False,
#    'view_count': 5,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786065,
#    'creation_date': 1583786065,
#    'question_id': 60607971,
#    'link': 'https://stackoverflow.com/questions/60607971/what-does-htmlelement-mean-in-typescript',
#    'title': 'What does HTMLElement[] mean in TypeScript?'},
#   {'tags': ['r', 'dataframe', 'nested-loops'],
#    'owner': {'reputation': 115,
#     'user_id': 12027869,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AAuE7mAQYKPvYRiYxFHDSP3a592_Efnhz-8_4v08wIT_Gfo=k-s128',
#     'display_name': 'Seunghoon Jung',
#     'link': 'https://stackoverflow.com/users/12027869/seunghoon-jung'},
#    'is_answered': False,
#    'view_count': 14,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786058,
#    'creation_date': 1583785478,
#    'question_id': 60607860,
#    'link': 'https://stackoverflow.com/questions/60607860/how-to-save-results-of-a-nested-loop-separately-for-each-unique-combination-in-r',
#    'title': 'How To Save Results Of A Nested Loop Separately For Each Unique Combination In R'},
#   {'tags': ['angular',
#     'ionic-framework',
#     'google-analytics',
#     'progressive-web-apps',
#     'offline'],
#    'owner': {'reputation': 1,
#     'user_id': 10111390,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-vmkKAHC0fKg/AAAAAAAAAAI/AAAAAAAAAAA/AAnnY7oa57DNiArakK0Mr_PKKcdzyzwJcQ/mo/photo.jpg?sz=128',
#     'display_name': 'JJ Lee',
#     'link': 'https://stackoverflow.com/users/10111390/jj-lee'},
#    'is_answered': False,
#    'view_count': 20,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583786057,
#    'creation_date': 1583567828,
#    'last_edit_date': 1583574866,
#    'question_id': 60575536,
#    'link': 'https://stackoverflow.com/questions/60575536/offline-google-analytics-for-pwa',
#    'title': 'Offline Google Analytics for PWA'},
#   {'tags': ['excel', 'vba', 'decimal'],
#    'owner': {'reputation': 13,
#     'user_id': 11493948,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-aBKhEliWTxs/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3rcrQ3-oPF7s9dbW6BSDb8rQ3hzjEQ/mo/photo.jpg?sz=128',
#     'display_name': 'Rafał Kowalski',
#     'link': 'https://stackoverflow.com/users/11493948/rafa%c5%82-kowalski'},
#    'is_answered': False,
#    'view_count': 7,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583786051,
#    'creation_date': 1583786051,
#    'question_id': 60607968,
#    'link': 'https://stackoverflow.com/questions/60607968/vba-decimal-places-for-multiple-formats',
#    'title': 'VBA - decimal places for multiple formats'},
#   {'tags': ['reactjs', 'react-props', 'react-state', 'react-lifecycle'],
#    'owner': {'reputation': 13,
#     'user_id': 12691299,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/32e7595346b16e308f009b8dbf533728?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Nate',
#     'link': 'https://stackoverflow.com/users/12691299/nate'},
#    'is_answered': False,
#    'view_count': 3,
#    'answer_count': 0,
#    'score': 1,
#    'last_activity_date': 1583786044,
#    'creation_date': 1583786044,
#    'question_id': 60607967,
#    'link': 'https://stackoverflow.com/questions/60607967/react-triggering-full-life-cycle-when-props-children-submitted-outside-render-me',
#    'title': 'React triggering full life-cycle when props children submitted outside render method'},
#   {'tags': ['podio'],
#    'owner': {'reputation': 11,
#     'user_id': 13035132,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/afd344f3d42554e62a4a40753f55ced8?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'screenvoid',
#     'link': 'https://stackoverflow.com/users/13035132/screenvoid'},
#    'is_answered': False,
#    'view_count': 5,
#    'answer_count': 1,
#    'score': 1,
#    'last_activity_date': 1583786036,
#    'creation_date': 1583784290,
#    'question_id': 60607599,
#    'link': 'https://stackoverflow.com/questions/60607599/podio-api-js-update-relationship-field-of-a-item',
#    'title': 'Podio API JS - Update relationship field of a Item'},
#   {'tags': ['java', 'javafx'],
#    'owner': {'reputation': 41,
#     'user_id': 12990975,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GgAQY7gBTMVkFTn53ekUNKOGXFYVBg_b3UWnQUj=k-s128',
#     'display_name': 'Mataske',
# ...
#    'last_edit_date': 1583784151,
#    'question_id': 60606143,
#    'link': 'https://stackoverflow.com/questions/60606143/split-string-after-certain-sequence-e-g-text-0000-text-text',
#    'title': 'Split string after certain sequence. E.g Text/0000/text/text'},
#   {'tags': ['mysql', 'hadoop', 'hive'],
#    'owner': {'reputation': 1091,
#     'user_id': 3544612,
#     'user_type': 'registered',
#     'accept_rate': 33,
#     'profile_image': 'https://www.gravatar.com/avatar/f8f624c3a53145fb23e91bc9b7f39f75?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Saurab',
#     'link': 'https://stackoverflow.com/users/3544612/saurab'},
#    'is_answered': False,
#    'view_count': 930,
#    'answer_count': 1,
#    'score': 2,
#    'last_activity_date': 1583784143,
#    'creation_date': 1501734483,
#    'question_id': 45474839,
#    'link': 'https://stackoverflow.com/questions/45474839/hive-version-compatible-with-spark',
#    'title': 'Hive version compatible with Spark'},
#   {'tags': ['swift4'],
#    'owner': {'reputation': 7,
#     'user_id': 11466047,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/803f4e31b5bf92fec8c2dfe7732023b7?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Rigsby',
#     'link': 'https://stackoverflow.com/users/11466047/rigsby'},
#    'is_answered': False,
#    'view_count': 9,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583784138,
#    'creation_date': 1583782445,
#    'last_edit_date': 1583784138,
#    'question_id': 60607236,
#    'link': 'https://stackoverflow.com/questions/60607236/uiimage-is-not-coming-below-buttonbarpagertabstripviewcontroller',
#    'title': 'UIImage is not coming below ButtonBarPagerTabStripViewController'},
#   {'tags': ['python'],
#    'owner': {'reputation': 10460,
#     'user_id': 266068,
#     'user_type': 'registered',
#     'accept_rate': 93,
#     'profile_image': 'https://i.stack.imgur.com/wzczi.png?s=128&g=1',
#     'display_name': 'Panos Kal.',
#     'link': 'https://stackoverflow.com/users/266068/panos-kal'},
#    'is_answered': True,
#    'view_count': 23,
#    'accepted_answer_id': 60607531,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1583784127,
#    'creation_date': 1583783114,
#    'last_edit_date': 1583783946,
#    'question_id': 60607368,
#    'link': 'https://stackoverflow.com/questions/60607368/convert-string-with-wrong-encoding-to-utf8',
#    'title': 'Convert string with wrong encoding to utf8'},
#   {'tags': ['php', 'mysql', 'xampp'],
#    'owner': {'reputation': 1,
#     'user_id': 11838167,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/558b69d59cec80f20c9438d6525980f2?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'wafa',
#     'link': 'https://stackoverflow.com/users/11838167/wafa'},
#    'is_answered': False,
#    'view_count': 8,
#    'closed_date': 1583784430,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583784121,
#    'creation_date': 1583784121,
#    'question_id': 60607567,
#    'link': 'https://stackoverflow.com/questions/60607567/how-to-setup-hospital-management-system-project-web-application-php-and-mysql-lo',
#    'closed_reason': 'Needs more focus',
#    'title': 'How to setup Hospital management system project web application PHP and MySQL locally on XAMPP server'},
#   {'tags': ['c++', 'printf', 'valgrind'],
#    'owner': {'reputation': 45,
#     'user_id': 7437667,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/3b60e02351be76c45db3a916ead0c04a?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Michael Sch&#228;fer',
#     'link': 'https://stackoverflow.com/users/7437667/michael-sch%c3%a4fer'},
#    'is_answered': True,
#    'view_count': 82,
#    'accepted_answer_id': 60589275,
#    'answer_count': 2,
#    'score': 1,
#    'last_activity_date': 1583784121,
#    'creation_date': 1583681182,
#    'last_edit_date': 1583784121,
#    'question_id': 60589006,
#    'link': 'https://stackoverflow.com/questions/60589006/c-sprintf-remove-undefined-behavior',
#    'title': 'c++ sprintf remove undefined behavior'},
#   {'tags': ['mysql', 'sql'],
#    'owner': {'reputation': 21,
#     'user_id': 5572373,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/916286248461195/picture?type=large',
#     'display_name': 'Andr&#233; Ribeiro',
#     'link': 'https://stackoverflow.com/users/5572373/andr%c3%a9-ribeiro'},
#    'is_answered': True,
#    'view_count': 27,
#    'answer_count': 1,
#    'score': 2,
#    'last_activity_date': 1583784120,
#    'creation_date': 1583526945,
#    'last_edit_date': 1583784120,
#    'question_id': 60571257,
#    'link': 'https://stackoverflow.com/questions/60571257/wordpress-mysql-query-copy-data-from-a-table-to-another',
#    'title': 'WordPress MySQL query: copy data from a table to another'},
#   {'tags': ['python', 'android', 'kivy'],
#    'owner': {'reputation': 1,
#     'user_id': 13035116,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/5ce39cee512447b94055fee9c4f23b5f?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'pltnoff',
#     'link': 'https://stackoverflow.com/users/13035116/pltnoff'},
#    'is_answered': False,
#    'view_count': 8,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583784116,
#    'creation_date': 1583784116,
#    'question_id': 60607566,
#    'link': 'https://stackoverflow.com/questions/60607566/kivy-application-crashes-on-android',
#    'title': 'Kivy application crashes on android'},
#   {'tags': ['angular', 'angular-material', 'jasmine'],
#    'owner': {'reputation': 1,
#     'user_id': 13034041,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/2c52137e5ce3aa5e374a7bd8a7c1e060?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'litzzem',
#     'link': 'https://stackoverflow.com/users/13034041/litzzem'},
#    'is_answered': False,
#    'view_count': 15,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583784116,
#    'creation_date': 1583774651,
#    'question_id': 60605539,
#    'link': 'https://stackoverflow.com/questions/60605539/how-to-test-matsort-with-jasmine',
#    'title': 'How to test MatSort with Jasmine'},
#   {'tags': ['kubernetes', 'kubernetes-helm', 'kubectl'],
#    'owner': {'reputation': 823,
#     'user_id': 1191181,
#     'user_type': 'registered',
#     'accept_rate': 29,
#     'profile_image': 'https://i.stack.imgur.com/oY8s4.jpg?s=128&g=1',
#     'display_name': 'user655321',
#     'link': 'https://stackoverflow.com/users/1191181/user655321'},
#    'is_answered': False,
#    'view_count': 15,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583784116,
#    'creation_date': 1583779901,
#    'last_edit_date': 1583784116,
#    'question_id': 60606669,
#    'link': 'https://stackoverflow.com/questions/60606669/how-do-i-upload-my-own-binary-python-module-as-a-resource-for-my-kubernetes-ap',
#    'title': 'How do I upload my own binary (Python module) as a resource for my Kubernetes application?'},
#   {'tags': ['java'],
#    'owner': {'reputation': 1,
#     'user_id': 12316996,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d28d6176a1298607cc9e9dd24eab793c?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Anonymous12',
#     'link': 'https://stackoverflow.com/users/12316996/anonymous12'},
#    'is_answered': False,
#    'view_count': 20,
#    'closed_date': 1583784964,
#    'answer_count': 0,
#    'score': -2,
#    'last_activity_date': 1583784111,
#    'creation_date': 1583783835,
#    'last_edit_date': 1583784111,
#    'question_id': 60607514,
#    'link': 'https://stackoverflow.com/questions/60607514/how-to-create-a-program-to-book-a-seat-loop-and-validating-user-inputs',
#    'closed_reason': 'Needs more focus',
#    'title': 'how to create a program to book a seat loop and validating user inputs?'},
#   {'tags': ['excel', 'vba'],
#    'owner': {'reputation': 11,
#     'user_id': 13021580,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-R5YOVy-g7D4/AAAAAAAAAAI/AAAAAAAAAAA/AKF05nAJ1GeM99lO1XCu3vwEq3YkGXCJCw/photo.jpg?sz=128',
#     'display_name': 'femwill',
#     'link': 'https://stackoverflow.com/users/13021580/femwill'},
#    'is_answered': False,
#    'view_count': 15,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583784108,
#    'creation_date': 1583783907,
#    'last_edit_date': 1583784108,
#    'question_id': 60607526,
#    'link': 'https://stackoverflow.com/questions/60607526/creating-a-report-in-separate-tab-based-on-matching-result-in-another',
#    'title': 'Creating a report in separate tab based on matching result in another'},
#   {'tags': ['php', 'wordpress'],
#    'owner': {'reputation': 1,
#     'user_id': 13035229,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/a6dd23d4bc0a6fd2bbc319cf738b882f?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'ScaryMovie2',
#     'link': 'https://stackoverflow.com/users/13035229/scarymovie2'},
#    'is_answered': False,
#    'view_count': 16,
#    'closed_date': 1583784933,
#    'answer_count': 0,
#    'score': -4,
#    'last_activity_date': 1583784108,
#    'creation_date': 1583784108,
#    'question_id': 60607564,
#    'link': 'https://stackoverflow.com/questions/60607564/warning-invalid-argument-supplied',
#    'closed_reason': 'Needs details or clarity',
#    'title': 'Warning : Invalid argument supplied'},
#   {'tags': ['python', 'stored-procedures', 'debian', 'mariadb'],
#    'owner': {'reputation': 23,
#     'user_id': 11389702,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/El3XH.jpg?s=128&g=1',
#     'display_name': 'Lewis Farnworth',
#     'link': 'https://stackoverflow.com/users/11389702/lewis-farnworth'},
#    'is_answered': False,
#    'view_count': 10,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583784099,
#    'creation_date': 1583781869,
#    'question_id': 60607110,
#    'link': 'https://stackoverflow.com/questions/60607110/python-cursor-callproc-function-not-calling-procedure',
#    'title': 'python cursor.callproc() function not calling procedure'},
#   {'tags': ['html',
#     'google-apps-script',
#     'window.open',
#     'google-apps-script-web-application'],
#    'owner': {'reputation': 167,
#     'user_id': 11381454,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-ddfFLCuHbQM/AAAAAAAAAAI/AAAAAAAAAAA/TmB4hDjVRfs/photo.jpg?sz=128',
#     'display_name': 'NMALM',
#     'link': 'https://stackoverflow.com/users/11381454/nmalm'},
#    'is_answered': False,
#    'view_count': 14,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583784095,
#    'creation_date': 1583781809,
#    'last_edit_date': 1583784095,
#    'question_id': 60607091,
#    'link': 'https://stackoverflow.com/questions/60607091/refreshing-a-page-opened-with-window-location-replace-or-window-openurl-self',
#    'title': 'Refreshing a page opened with window.location.replace or window.open(url,&#39;_self&#39;) takes me to previous window'},
#   {'tags': ['objective-c', 'nsdictionary'],
#    'owner': {'reputation': 55,
#     'user_id': 1319480,
#     'user_type': 'registered',
#     'accept_rate': 0,
#     'profile_image': 'https://www.gravatar.com/avatar/4da18279eaa79697a8b5a075cb3bbff0?s=128&d=identicon&r=PG',
#     'display_name': 'shay nagar',
#     'link': 'https://stackoverflow.com/users/1319480/shay-nagar'},
#    'is_answered': False,
#    'view_count': 6240,
#    'answer_count': 2,
#    'score': 3,
#    'last_activity_date': 1583784085,
#    'creation_date': 1334061174,
#    'last_edit_date': 1370087241,
#    'question_id': 10088872,
#    'link': 'https://stackoverflow.com/questions/10088872/how-to-use-nsdictionary',
#    'title': 'how to use NSDictionary'},
#   {'tags': ['jquery', 'sharepoint', 'web-parts'],
#    'owner': {'reputation': 21,
#     'user_id': 1718231,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/1512e37891d55dbbde445ba8dc13e51b?s=128&d=identicon&r=PG',
#     'display_name': 'Shiva Vaid',
#     'link': 'https://stackoverflow.com/users/1718231/shiva-vaid'},
#    'is_answered': False,
#    'view_count': 6079,
#    'answer_count': 4,
#    'score': 2,
#    'last_activity_date': 1583784085,
#    'creation_date': 1349295924,
#    'last_edit_date': 1349361995,
#    'question_id': 12716327,
#    'link': 'https://stackoverflow.com/questions/12716327/jquery-in-visual-web-part-sharepoint-foundation',
#    'title': 'JQuery in Visual Web Part SharePoint Foundation'},
#   {'tags': ['microstrategy'],
#    'owner': {'reputation': 21,
#     'user_id': 3058079,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/348dfc878702ca263f3d4f6d6608a094?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'user3058079',
#     'link': 'https://stackoverflow.com/users/3058079/user3058079'},
#    'is_answered': False,
#    'view_count': 6503,
#    'answer_count': 2,
#    'score': 0,
#    'last_activity_date': 1583784085,
#    'creation_date': 1386008832,
#    'question_id': 20335200,
#    'link': 'https://stackoverflow.com/questions/20335200/force-microstrategy-to-use-specific-table-in-join',
#    'title': 'Force Microstrategy to use specific table in join'},
#   {'tags': ['ios', 'objective-c', 'iphone', 'ipad'],
#    'owner': {'reputation': 51,
#     'user_id': 5047214,
#     'user_type': 'registered',
#     'accept_rate': 20,
#     'profile_image': 'https://www.gravatar.com/avatar/65fe3040a686acebac3678a34a36d80f?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'thisguy',
#     'link': 'https://stackoverflow.com/users/5047214/thisguy'},
#    'is_answered': False,
#    'view_count': 6393,
#    'answer_count': 1,
#    'score': 0,
#    'last_activity_date': 1583784085,
#    'creation_date': 1437104556,
#    'question_id': 31468062,
#    'link': 'https://stackoverflow.com/questions/31468062/how-to-rotate-a-photo-on-iphone-only',
#    'title': 'How to rotate a photo on iPhone only?'},
#   {'tags': ['types', 'rust'],
#    'owner': {'reputation': 27645,
#     'user_id': 527288,
#     'user_type': 'registered',
#     'accept_rate': 81,
#     'profile_image': 'https://www.gravatar.com/avatar/9e175031c4adde62f40456f86a5e91b0?s=128&d=identicon&r=PG',
#     'display_name': 'Kurtis Nusbaum',
#     'link': 'https://stackoverflow.com/users/527288/kurtis-nusbaum'},
#    'is_answered': True,
#    'view_count': 1029,
#    'accepted_answer_id': 27673705,
#    'answer_count': 2,
#    'score': 12,
#    'last_activity_date': 1583784078,
#    'creation_date': 1419740429,
#    'last_edit_date': 1583783903,
#    'question_id': 27673674,
#    'link': 'https://stackoverflow.com/questions/27673674/is-there-a-way-to-create-a-data-type-that-only-accepts-a-range-of-values',
#    'title': 'Is there a way to create a data type that only accepts a range of values?'},
#   {'tags': ['spring-boot',
#     'db2',
#     'integration-testing',
#     'h2',
#     'spring-boot-test'],
#    'owner': {'reputation': 859,
#     'user_id': 3229501,
#     'user_type': 'registered',
#     'accept_rate': 79,
#     'profile_image': 'https://www.gravatar.com/avatar/5bd547a5ded64ad28cf242ce704aa572?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'SnoopDougg',
#     'link': 'https://stackoverflow.com/users/3229501/snoopdougg'},
#    'is_answered': False,
#    'view_count': 8,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583784077,
#    'creation_date': 1583784077,
#    'question_id': 60607560,
#    'link': 'https://stackoverflow.com/questions/60607560/how-to-configure-h2-database-queries-to-ignore-trailing-whitespace',
#    'title': 'How to configure H2 database queries to ignore trailing whitespace?'},
#   {'tags': ['javascript', 'typescript', 'decorator'],
#    'owner': {'reputation': 75,
#     'user_id': 11065277,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/639149879851807/picture?type=large',
#     'display_name': 'Marcelo Perrella',
#     'link': 'https://stackoverflow.com/users/11065277/marcelo-perrella'},
#    'is_answered': False,
#    'view_count': 12,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1583784075,
#    'creation_date': 1583784075,
#    'question_id': 60607557,
#    'link': 'https://stackoverflow.com/questions/60607557/typescript-decorator-to-define-method-signature',
#    'title': 'Typescript decorator to define method signature'}]}

# %%
answ = pd.DataFrame(answ)

# %%
quest['accepted_answer_id']
# Out:
# 0      60607996.0
# 1             NaN
# 2      60607737.0
# 3      60607938.0
# 4             NaN
#           ...
# 495           NaN
# 496           NaN
# 497    27673705.0
# 498           NaN
# 499           NaN
# Name: accepted_answer_id, Length: 500, dtype: float64

# %%
answ = SITE.fetch('answers/{}', ids=[1,2,3])
# Out:
# ---------------------------------------------------------------------------
# StackAPIError                             Traceback (most recent call last)
# <ipython-input-67-24f06bbda460> in <module>
# ----> 1 answ = SITE.fetch('answers/{}', ids=[1,2,3])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/stackapi/stackapi.py in fetch(self, endpoint, page, key, filter, **kwargs)
#     196                 code = response["error_name"]
#     197                 message = response["error_message"]
# --> 198                 raise StackAPIError(self._previous_call, error, code, message)
#     199             except KeyError:
#     200                 pass  # This means there is no error
#
# StackAPIError: ('https://api.stackexchange.com/2.2/answers/%7B%7D/1;2;3/?pagesize=100&page=1&filter=default&site=stackoverflow', 404, 'no_method', 'no method found with this name')
