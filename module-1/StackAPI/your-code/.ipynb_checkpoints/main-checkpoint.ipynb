# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here
import pandas as pd

from stackapi import StackAPI
SITE = StackAPI('stackoverflow')

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# your code here
questions = SITE.fetch('questions', fromdate=1580515200, todate=1583020799)

# %%
questions['items'][0]
# Out:
# {'tags': ['tensorflow', 'keras'],
#  'owner': {'reputation': 21,
#   'user_id': 4971706,
#   'user_type': 'registered',
#   'profile_image': 'https://www.gravatar.com/avatar/886b059353e124f7dbb446631ee96408?s=128&d=identicon&r=PG&f=1',
#   'display_name': 'Reid Swanson',
#   'link': 'https://stackoverflow.com/users/4971706/reid-swanson'},
#  'is_answered': True,
#  'view_count': 29,
#  'accepted_answer_id': 60936291,
#  'answer_count': 1,
#  'score': 0,
#  'last_activity_date': 1585590038,
#  'creation_date': 1582839500,
#  'question_id': 60442117,
#  'link': 'https://stackoverflow.com/questions/60442117/model-fit-with-tensorflow-2-1-and-tf-data-dataset-valueerror-attempt-to-convert',
#  'title': 'model.fit with tensorflow 2.1 and tf.data.Dataset ValueError: Attempt to convert a value TensorSpec'}

# %%
quest = pd.DataFrame(questions['items'])

# %%
quest
# Out:
#                                                   tags  \
# 0                                  [tensorflow, keras]
# 1                                            [flutter]
# 2                              [c#, wpf, data-binding]
# 3                                   [oculus, agora.io]
# 4                                   [python, pygments]
# ..                                                 ...
# 495  [swift, xcode, uinavigationcontroller, uinavig...
# 496                                 [node.js, mongodb]
# 497      [sql, regex, database, postgresql, algorithm]
# 498           [macos, terminal, xcode11.3, opensmiles]
# 499                               [android-studio-3.6]
#
#                                                  owner  is_answered  \
# 0    {'reputation': 21, 'user_id': 4971706, 'user_t...         True
# 1    {'reputation': 319, 'user_id': 11222495, 'user...         True
# 2    {'reputation': 246, 'user_id': 6346570, 'user_...        False
# 3    {'reputation': 11, 'user_id': 12262401, 'user_...        False
# 4    {'reputation': 3779, 'user_id': 1208142, 'user...        False
# ..                                                 ...          ...
# 495  {'reputation': 11, 'user_id': 8714290, 'user_t...        False
# 496  {'reputation': 1, 'user_id': 12972632, 'user_t...         True
# 497  {'reputation': 236, 'user_id': 8909621, 'user_...         True
# 498  {'reputation': 11, 'user_id': 12931924, 'user_...        False
# 499  {'reputation': 117, 'user_id': 10496632, 'user...         True
#
#      view_count  accepted_answer_id  answer_count  score  last_activity_date  \
# 0            29          60936291.0             1      0          1585590038
# 1           505          60274203.0             3      5          1585589952
# 2            53                 NaN             1      1          1585589740
# 3            53                 NaN             2      0          1585589712
# 4            25                 NaN             1      0          1585589493
# ..          ...                 ...           ...    ...                 ...
# 495          40                 NaN             0      0          1585214008
# 496         960                 NaN             3      0          1585213960
# 497          41          60401231.0             2      0          1585212853
# 498          64                 NaN             1      1          1585212755
# 499         418          60863638.0             1      5          1585212548
#
#      creation_date  question_id  \
# 0       1582839500     60442117
# 1       1581962707     60268180
# 2       1582718187     60413391
# 3       1582047437     60286561
# 4       1582942021     60461374
# ..             ...          ...
# 495     1582536950     60372992
# 496     1582802049     60431996
# 497     1582643378     60397698
# 498     1582201885     60320004
# 499     1582795383     60429919
#
#                                                   link  \
# 0    https://stackoverflow.com/questions/60442117/m...
# 1    https://stackoverflow.com/questions/60268180/f...
# 2    https://stackoverflow.com/questions/60413391/w...
# 3    https://stackoverflow.com/questions/60286561/a...
# 4    https://stackoverflow.com/questions/60461374/f...
# ..                                                 ...
# 495  https://stackoverflow.com/questions/60372992/i...
# 496  https://stackoverflow.com/questions/60431996/m...
# 497  https://stackoverflow.com/questions/60397698/w...
# 498  https://stackoverflow.com/questions/60320004/e...
# 499  https://stackoverflow.com/questions/60429919/a...
#
#                                                  title  last_edit_date  \
# 0    model.fit with tensorflow 2.1 and tf.data.Data...             NaN
# 1    Flutter Outline Shows &quot;Nothing to show&qu...    1.582080e+09
# 2          WPF : Binding only working when using Snoop             NaN
# 3    Agora.io: android.permission.CAMERA not compat...             NaN
# 4     Font not found with Pygments&#39; ImageFormatter             NaN
# ..                                                 ...             ...
# 495  Is there a bug with &#39;Prefers large titles&...             NaN
# 496  MongooseError [MongooseServerSelectionError]: ...    1.582811e+09
# 497  What exactly differs fuzzy search from Full Te...    1.585213e+09
# 498  &#39;Error: no member named &#39;signbit&#39; ...             NaN
# 499  Android Studio 3.6 is constantly asking to ins...    1.582813e+09
#
#      bounty_amount  bounty_closes_date  closed_date closed_reason  \
# 0              NaN                 NaN          NaN           NaN
# 1              NaN                 NaN          NaN           NaN
# 2              NaN                 NaN          NaN           NaN
# 3              NaN                 NaN          NaN           NaN
# 4              NaN                 NaN          NaN           NaN
# ..             ...                 ...          ...           ...
# 495            NaN                 NaN          NaN           NaN
# 496            NaN                 NaN          NaN           NaN
# 497            NaN                 NaN          NaN           NaN
# 498            NaN                 NaN          NaN           NaN
# 499            NaN                 NaN          NaN           NaN
#
#      protected_date migrated_from
# 0               NaN           NaN
# 1               NaN           NaN
# 2               NaN           NaN
# 3               NaN           NaN
# 4               NaN           NaN
# ..              ...           ...
# 495             NaN           NaN
# 496             NaN           NaN
# 497             NaN           NaN
# 498             NaN           NaN
# 499             NaN           NaN
#
# [500 rows x 19 columns]

# %%
answers = SITE.fetch('answers', fromdate=1580515200, todate=1583020799)

# %%
answ = pd.DataFrame(answers['items'])

# %%
answ.head()
# Out:
#                                                owner  is_accepted  score  \
# 0  {'reputation': 9640, 'user_id': 3702377, 'user...        False      1
# 1  {'reputation': 97, 'user_id': 2243871, 'user_t...        False      1
# 2  {'reputation': 409, 'user_id': 7496663, 'user_...        False      1
# 3  {'reputation': 409, 'user_id': 7496663, 'user_...        False      0
# 4  {'reputation': 7283, 'user_id': 4533188, 'user...         True      0
#
#    last_activity_date  last_edit_date  creation_date  answer_id  question_id  \
# 0          1585588370      1585588370     1582899964   60453701     44623184
# 1          1585587223      1585587223     1581166772   60127007     47593692
# 2          1585578975      1585578975     1580738203   60040713     43726009
# 3          1585578779      1585578779     1580737992   60040647     20690470
# 4          1585577784      1585577784     1581611145   60212467     60210917
#
#    community_owned_date
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here

questions = SITE.fetch('questions', fromdate=1583712000, todate=1583785860,
    tagged='python', sort='votes')

# %%
questions['items'][0]
# Out:
# {'tags': ['python', 'recursion'],
#  'owner': {'reputation': 524,
#   'user_id': 4443051,
#   'user_type': 'registered',
#   'accept_rate': 100,
#   'profile_image': 'https://i.stack.imgur.com/g4Sim.jpg?s=128&g=1',
#   'display_name': 'Mercado',
#   'link': 'https://stackoverflow.com/users/4443051/mercado'},
#  'is_answered': True,
#  'view_count': 3532,
#  'accepted_answer_id': 60596253,
#  'answer_count': 2,
#  'score': 6,
#  'last_activity_date': 1583749483,
#  'creation_date': 1583735078,
#  'last_edit_date': 1583739468,
#  'question_id': 60595571,
#  'link': 'https://stackoverflow.com/questions/60595571/recursion-without-referencing-and-assignment',
#  'title': 'Recursion without Referencing and Assignment'}

# %%
import pandas as pd

quest = pd.DataFrame(questions['items'])

# %%
quest['title'].head(5)
# Out:
# 0         Recursion without Referencing and Assignment
# 1    Partial keyword match not working when I am tr...
# 2    Find row average of tuples in data frame / 2d ...
# 3    Modify trained model architecture and continue...
# 4    How do I make independent lists within in a list?
# Name: title, dtype: object

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here
answ = SITE.fetch('answers/{ids}', ids=[6784,6473])

# %%
answ
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 28657,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778}]}
